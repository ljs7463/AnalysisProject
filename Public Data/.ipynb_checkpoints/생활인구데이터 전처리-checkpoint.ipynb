# %%
import sys
import os
os.getcwd()
# Out:
# '/Users/jeongseok/Documents/GitHub/AnalysisProject/Public Data'

# %%
os.listdir()
# Out:
# ['.DS_Store', '.ipynb_checkpoints', '생활인구데이터 전처리.ipynb', '서울시인구데이터']

# %%
import pandas as pd

seoul = pd.read_csv('./서울시인구데이터/서울시 생활인구데이터.csv')
mapping = pd.read_csv('./서울시인구데이터/행정동 코드 매핑 테이블.csv')

# %%
seoul
# Out:
#           기준일ID     시간대구분       행정동코드     총생활인구수  남자0세부터9세생활인구수  \
# 20220301      0  11110515  15101.8130   511.2472       325.7679
# 20220301      0  11110530  12195.7307   284.5014       126.4451
# 20220301      0  11110540   3495.7127    51.4900        39.4535
# 20220301      0  11110550  15542.6773   442.4892       343.0999
# 20220301      0  11110560  18662.1008   626.5593       453.2105
# ...         ...       ...         ...        ...            ...
# 20220331     23  11290580  15361.8384   435.8650       300.0112
# 20220331     23  11650581  34273.6212  1865.9757      1063.0400
# 20220331     23  11140615  27071.3324   145.0207       105.6741
# 20220331     23  11710647  47525.9965  5264.9228      1746.5850
# 20220331     23  11530595  11223.5626    98.3772        50.6495
#
#           남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 20220301         505.3072         507.6178         520.0308         493.9273
# ...

# %%
# Check data Type
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 315456 entries, 20220301 to 20220331
# Data columns (total 32 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   기준일ID            315456 non-null  int64
#  1   시간대구분            315456 non-null  int64
#  2   행정동코드            315456 non-null  float64
#  3   총생활인구수           315456 non-null  float64
#  4   남자0세부터9세생활인구수    315456 non-null  float64
#  5   남자10세부터14세생활인구수  315456 non-null  float64
#  6   남자15세부터19세생활인구수  315456 non-null  float64
#  7   남자20세부터24세생활인구수  315456 non-null  float64
#  8   남자25세부터29세생활인구수  315456 non-null  float64
#  9   남자30세부터34세생활인구수  315456 non-null  float64
#  10  남자35세부터39세생활인구수  315456 non-null  float64
#  11  남자40세부터44세생활인구수  315456 non-null  float64
#  12  남자45세부터49세생활인구수  315456 non-null  float64
#  13  남자50세부터54세생활인구수  315456 non-null  float64
#  14  남자55세부터59세생활인구수  315456 non-null  float64
#  15  남자60세부터64세생활인구수  315456 non-null  float64
# ...

# %%
seoul['행정동코드']
# Out:
# 20220301    15101.8130
# 20220301    12195.7307
# 20220301     3495.7127
# 20220301    15542.6773
# 20220301    18662.1008
#                ...
# 20220331    15361.8384
# 20220331    34273.6212
# 20220331    27071.3324
# 20220331    47525.9965
# 20220331    11223.5626
# Name: 행정동코드, Length: 315456, dtype: float64

# %%
seoul['행정동코드']

# %%
mapping
# Out:
#       Unnamed: 0   hdongCode  sigunguCode sidoName sigunguName hdongName
# 0              0  1100000000        11000    서울특별시         NaN       NaN
# 1              1  1111000000        11110    서울특별시         종로구       NaN
# 2              2  1111051000        11110    서울특별시         종로구       청운동
# 3              3  1111051500        11110    서울특별시         종로구     청운효자동
# 4              4  1111052000        11110    서울특별시         종로구       효자동
# ...          ...         ...          ...      ...         ...       ...
# 8488        8488  5013058000        50130  제주특별자치도        서귀포시       서홍동
# 8489        8489  5013059000        50130  제주특별자치도        서귀포시       대륜동
# 8490        8490  5013060000        50130  제주특별자치도        서귀포시       대천동
# 8491        8491  5013061000        50130  제주특별자치도        서귀포시       중문동
# 8492        8492  5013062000        50130  제주특별자치도        서귀포시       예래동
#
# [8493 rows x 6 columns]
