# %% [markdown]
# ## 분석의 목적 :각나라의 디즈니랜드의 평가가 어떤지 알아보고 부정의 리뷰를 통해 고객들의 니즈가 무엇인지 파악하여 개선방법을 찾아보자

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\python37\lib\site-packages (3.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\python37\lib\site-packages (from spacy) (20.4)
# Requirement already satisfied: setuptools in c:\python37\lib\site-packages (from spacy) (41.2.0)
# Requirement already satisfied: jinja2 in c:\python37\lib\site-packages (from spacy) (3.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python37\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\python37\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\python37\lib\site-packages (from spacy) (1.19.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\python37\lib\site-packages (from spacy) (0.3.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python37\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\python37\lib\site-packages (from spacy) (2.25.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\python37\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python37\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\python37\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in c:\python37\lib\site-packages (from spacy) (8.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\python37\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\python37\lib\site-packages (from spacy) (4.50.1)
# Requirement already satisfied: pathy>=0.3.5 in c:\python37\lib\site-packages (from spacy) (0.6.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\python37\lib\site-packages (from spacy) (2.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in c:\python37\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in c:\python37\lib\site-packages (from spacy) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in c:\python37\lib\site-packages (from catalogue<2.1.0,>=2.0.4->spacy) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\python37\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: six in c:\python37\lib\site-packages (from packaging>=20.0->spacy) (1.15.0)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\python37\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python37\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\python37\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\python37\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python37\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.2)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\python37\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python37\lib\site-packages (from jinja2->spacy) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\python37\python.exe -m pip install --upgrade pip' command.

# %%
pip install afinn
# Out:
# Requirement already satisfied: afinn in c:\python37\lib\site-packages (0.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\python37\python.exe -m pip install --upgrade pip' command.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\python37\lib\site-packages (3.6.2)
# Requirement already satisfied: click in c:\python37\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in c:\python37\lib\site-packages (from nltk) (4.50.1)
# Requirement already satisfied: regex in c:\python37\lib\site-packages (from nltk) (2021.8.28)
# Requirement already satisfied: joblib in c:\python37\lib\site-packages (from nltk) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\python37\python.exe -m pip install --upgrade pip' command.

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\python37\lib\site-packages (4.1.0)
# Requirement already satisfied: Cython==0.29.23 in c:\python37\lib\site-packages (from gensim) (0.29.23)
# Requirement already satisfied: numpy>=1.17.0 in c:\python37\lib\site-packages (from gensim) (1.19.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\python37\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in c:\python37\lib\site-packages (from gensim) (1.6.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\python37\python.exe -m pip install --upgrade pip' command.

# %%
# 언어모델 다운받기
# !python -m spacy download en
# Out:
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in c:\python37\lib\site-packages (from en-core-web-sm==3.1.0) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.50.1)
# Requirement already satisfied: jinja2 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (20.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.19.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.7.4.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.25.0)
# Requirement already satisfied: setuptools in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (41.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.3.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\python37\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\python37\lib\site-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\python37\lib\site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: six in c:\python37\lib\site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.15.0)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\python37\lib\site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python37\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\python37\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python37\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\python37\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\python37\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python37\lib\site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.1)
# [!] As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the full
# pipeline package name 'en_core_web_sm' instead.
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp37-cp37m-win_amd64.whl (154 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\python37\lib\site-packages (from wordcloud) (1.19.3)
# Requirement already satisfied: matplotlib in c:\python37\lib\site-packages (from wordcloud) (3.4.2)
# Requirement already satisfied: pillow in c:\python37\lib\site-packages (from wordcloud) (8.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python37\lib\site-packages (from matplotlib->wordcloud) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python37\lib\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python37\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\python37\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: six in c:\python37\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.15.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.1
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\python37\python.exe -m pip install --upgrade pip' command.

# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.15.3-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\python37\lib\site-packages (from textblob) (3.6.2)
# Requirement already satisfied: click in c:\python37\lib\site-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: joblib in c:\python37\lib\site-packages (from nltk>=3.1->textblob) (1.0.1)
# Requirement already satisfied: regex in c:\python37\lib\site-packages (from nltk>=3.1->textblob) (2021.8.28)
# Requirement already satisfied: tqdm in c:\python37\lib\site-packages (from nltk>=3.1->textblob) (4.50.1)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\python37\python.exe -m pip install --upgrade pip' command.

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in c:\python37\lib\site-packages (from folium) (1.20.0)
# Requirement already satisfied: requests in c:\python37\lib\site-packages (from folium) (2.25.0)
# Requirement already satisfied: jinja2>=2.9 in c:\python37\lib\site-packages (from folium) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python37\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python37\lib\site-packages (from requests->folium) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python37\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\python37\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\python37\lib\site-packages (from requests->folium) (3.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\python37\python.exe -m pip install --upgrade pip' command.

# %%
# 필요한 라이브러리 불러오기
import pandas as pd
import numpy as np
import spacy
import re
import seaborn as sns
import matplotlib.pyplot as plt
import folium


from spacy.tokenizer import Tokenizer
from nltk.corpus import stopwords 
from textblob import TextBlob
from wordcloud import WordCloud

# %%
# 데이터 로드
df = pd.read_csv('Raw_data.csv',encoding='latin1')
df
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4      the location is not in the city, took around 1...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  i went to disneyland paris in july 03 and thou...     Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...     Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...     Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...     Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...     Disneyland_Paris
#
# [42656 rows x 6 columns]

# %%
from gensim.summarization.summarizer import summarize
text= df['Review_Text'][5]
summarize(text, word_count =20)
# Out:
# 'Basically, this park is good only for small children and people who has never been to Disney.'

# %%
df['Review_Text'][5]
# Out:
# "Have been to Disney World, Disneyland Anaheim and Tokyo Disneyland but I feel that Disneyland Hong Kong is really too small to be called a Disneyland. It has way too few rides and attractions. Souvenirs, food and even entrance tickets are slightly more expensive than other Disneyland as well. Basically, this park is good only for small children and people who has never been to Disney. The food choices were acceptable, mostly fast food, and not too expensive. Bottled water, however, was VERY expensive but they do have water fountains around for you to refill your water bottles. The parade was pretty good. It was crowded not a problem but what was the problem was the people were just so rude, the pushing and shoving cutting in lines for the rides, gift shops, food stands was just to much to take. forget trying to see one of the shows its a free for all for seats, i don't see how Disney can let this happen, it was by far the worst managed Disney property."

# %%
from gensim.summarization.summarizer import summarize
text= df['Review_Text'][4]
summarize(text, word_count =20)
# Out:
# ''

# %%
df['Review_Text'][4]
# Out:
# 'the location is not in the city, took around 1 hour from Kowlon, my kids like disneyland so much, everything is fine.   but its really crowded and hot in Hong Kong'

# %%
# 데이터 탐색
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42656 entries, 0 to 42655
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          42656 non-null  int64
#  1   Rating             42656 non-null  int64
#  2   Year_Month         42656 non-null  object
#  3   Reviewer_Location  42656 non-null  object
#  4   Review_Text        42656 non-null  object
#  5   Branch             42656 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 2.0+ MB

# %%
# 결측값 확인
df.isnull().sum()
# Out:
# Review_ID            0
# Rating               0
# Year_Month           0
# Reviewer_Location    0
# Review_Text          0
# Branch               0
# dtype: int64

# %%
# 필요없는 컬럼 제거
df = df.drop(columns = ['Review_ID', 'Year_Month'])
df
# Out:
#        Rating     Reviewer_Location  \
# 0           4             Australia
# 1           4           Philippines
# 2           4  United Arab Emirates
# 3           4             Australia
# 4           4        United Kingdom
# ...       ...                   ...
# 42651       5        United Kingdom
# 42652       5                Canada
# 42653       5          South Africa
# 42654       4         United States
# 42655       4        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4      the location is not in the city, took around 1...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  i went to disneyland paris in july 03 and thou...     Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...     Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...     Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...     Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...     Disneyland_Paris
#
# [42656 rows x 4 columns]

# %%
# 국가의 종류 확인
df['Branch'].unique()
# Out:
# array(['Disneyland_HongKong', 'Disneyland_California', 'Disneyland_Paris'],
#       dtype=object)

# %%
# 리뷰 컬럼 확인
df['Review_Text']
# Out:
# 0        If you've ever been to Disneyland anywhere you...
# 1        Its been a while since d last time we visit HK...
# 2        Thanks God it wasn   t too hot or too humid wh...
# 3        HK Disneyland is a great compact park. Unfortu...
# 4        the location is not in the city, took around 1...
#                                ...
# 42651    i went to disneyland paris in july 03 and thou...
# 42652    2 adults and 1 child of 11 visited Disneyland ...
# 42653    My eleven year old daughter and myself went to...
# 42654    This hotel, part of the Disneyland Paris compl...
# 42655    I went to the Disneyparis resort, in 1996, wit...
# Name: Review_Text, Length: 42656, dtype: object

# %%
nlp = spacy.load("en_core_web_sm")

tokenizer = Tokenizer(nlp.vocab)

# %%
# 해당코드는 if절이 걸리지 않았음 오류코드

# # 토큰화를 위한 파이프라인 구성
 
# tokens = []
# stop_words = stopwords.words('english')

# for doc in tokenizer.pipe(df['Review_Text']):
#     if doc not in stop_words:
#         doc_tokens = [re.sub(r"[^a-z0-9]", "", token.text.lower()) for token in doc]
#         tokens.append(doc_tokens)
    
# df['Review_Text'] = tokens[:]
# df['Review_Text'].head()

# %% [markdown]
# 불용어 제거를 위해 참고한 링크 : <https://lemontia.tistory.com/802>

# %%
# 토큰화를 위한 파이프라인 구성
 
tokens = []
stop_words = stopwords.words('english')

for doc in tokenizer.pipe(df['Review_Text']):
   
    doc_tokens = [re.sub(r"[^a-z0-9]", "", token.text.lower()) for token in doc if re.sub(r"[^a-z0-9]", "",token.text.lower()) not in stop_words]
    tokens.append(doc_tokens)
    
df['Review_Text'] = tokens[:]
df['Review_Text'].head()
# Out:
# 0    [youve, ever, disneyland, anywhere, youll, fin...
# 1    [since, last, time, visit, hk, disneyland, , y...
# 2    [thanks, god, , hot, humid, visiting, park, , ...
# 3    [hk, disneyland, great, compact, park, unfortu...
# 4    [location, city, took, around, 1, hour, kowlon...
# Name: Review_Text, dtype: object

# %%
def getPolarity(text):
   return  TextBlob(text).sentiment.polarity

df['Polarity'] = df['Review_Text'].apply(lambda x: getPolarity(' '.join(x))) # join함수 를 통해 리스트를 문자열로 바꿔서 에러해결
df

# 여기서 걸린 에러 해결 
# <https://textblob.readthedocs.io/en/dev/quickstart.html>
# <https://stackoverflow.com/questions/62611786/textblob-tweets-typeerror-the-text-argument-passed-to-init-text-must>
# Out:
#        Rating     Reviewer_Location  \
# 0           4             Australia
# 1           4           Philippines
# 2           4  United Arab Emirates
# 3           4             Australia
# 4           4        United Kingdom
# ...       ...                   ...
# 42651       5        United Kingdom
# 42652       5                Canada
# 42653       5          South Africa
# 42654       4         United States
# 42655       4        United Kingdom
#
#                                              Review_Text               Branch  \
# 0      [youve, ever, disneyland, anywhere, youll, fin...  Disneyland_HongKong
# 1      [since, last, time, visit, hk, disneyland, , y...  Disneyland_HongKong
# 2      [thanks, god, , hot, humid, visiting, park, , ...  Disneyland_HongKong
# 3      [hk, disneyland, great, compact, park, unfortu...  Disneyland_HongKong
# 4      [location, city, took, around, 1, hour, kowlon...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  [went, disneyland, paris, july, 03, thought, b...     Disneyland_Paris
# 42652  [2, adults, 1, child, 11, visited, disneyland,...     Disneyland_Paris
# 42653  [eleven, year, old, daughter, went, visit, son...     Disneyland_Paris
# 42654  [hotel, part, disneyland, paris, complex, wond...     Disneyland_Paris
# 42655  [went, disneyparis, resort, 1996, small, child...     Disneyland_Paris
#
#        Polarity
# 0      0.226852
# 1      0.209524
# 2      0.226548
# 3      0.222222
# 4      0.266667
# ...         ...
# 42651  0.252778
# 42652  0.178333
# 42653  0.212500
# 42654  0.253480
# 42655  0.247381
#
# [42656 rows x 5 columns]

# %%
def getAnalysis(score):
 if score < 0:
  return 'Negative'
 elif score == 0:
  return 'Neutral'
 else:
  return 'Positive'

df['Analysis'] = df['Polarity'].apply(getAnalysis)
df
# Out:
#        Rating     Reviewer_Location  \
# 0           4             Australia
# 1           4           Philippines
# 2           4  United Arab Emirates
# 3           4             Australia
# 4           4        United Kingdom
# ...       ...                   ...
# 42651       5        United Kingdom
# 42652       5                Canada
# 42653       5          South Africa
# 42654       4         United States
# 42655       4        United Kingdom
#
#                                              Review_Text               Branch  \
# 0      [youve, ever, disneyland, anywhere, youll, fin...  Disneyland_HongKong
# 1      [since, last, time, visit, hk, disneyland, , y...  Disneyland_HongKong
# 2      [thanks, god, , hot, humid, visiting, park, , ...  Disneyland_HongKong
# 3      [hk, disneyland, great, compact, park, unfortu...  Disneyland_HongKong
# 4      [location, city, took, around, 1, hour, kowlon...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  [went, disneyland, paris, july, 03, thought, b...     Disneyland_Paris
# 42652  [2, adults, 1, child, 11, visited, disneyland,...     Disneyland_Paris
# 42653  [eleven, year, old, daughter, went, visit, son...     Disneyland_Paris
# 42654  [hotel, part, disneyland, paris, complex, wond...     Disneyland_Paris
# 42655  [went, disneyparis, resort, 1996, small, child...     Disneyland_Paris
#
#        Polarity  Analysis
# 0      0.226852  Positive
# 1      0.209524  Positive
# 2      0.226548  Positive
# 3      0.222222  Positive
# 4      0.266667  Positive
# ...         ...       ...
# 42651  0.252778  Positive
# 42652  0.178333  Positive
# 42653  0.212500  Positive
# 42654  0.253480  Positive
# 42655  0.247381  Positive
#
# [42656 rows x 6 columns]

# %%
df['Analysis'].value_counts()
# Out:
# Positive    38419
# Negative     3813
# Neutral       424
# Name: Analysis, dtype: int64

# %%
# 디즈니랜드 국가별 데이터 프레임 생성
df_HongKong = df[df['Branch']=='Disneyland_HongKong']
df_California = df[df['Branch']=='Disneyland_California']
df_Paris = df[df['Branch']=='Disneyland_Paris']

# %%
print('홍콩 데이터 길이: ',len(df_HongKong['Analysis']))
print('캘리포니아 데이터 길이: ',len(df_California['Analysis']))
print('파리 데이터 길이: ',len(df_Paris['Analysis']))
# Out:
# 홍콩 데이터 길이:  9620
# 캘리포니아 데이터 길이:  19406
# 파리 데이터 길이:  13630

# %%
print(df_HongKong['Analysis'].value_counts())
print('------------')
print(df_California['Analysis'].value_counts())
print('------------')
print(df_Paris['Analysis'].value_counts())
# Out:
# Positive    8757
# Negative     768
# Neutral       95
# Name: Analysis, dtype: int64
# ------------
# Positive    17632
# Negative     1531
# Neutral       243
# Name: Analysis, dtype: int64
# ------------
# Positive    12030
# Negative     1514
# Neutral        86
# Name: Analysis, dtype: int64

# %%
sns.set_context('notebook')

fig, ax = plt.subplots(1,3,figsize = (12,5))

sizes = [8757/len(df_HongKong['Analysis']), 768/len(df_HongKong['Analysis']), 95/len(df_HongKong['Analysis'])]
labels = ['Positive', 'Negative', 'Neutral']

pathes, texts, autotexts = ax[0].pie(sizes, 
                                    labels = labels,
                                    autopct = '%1.1f%%',
                                    shadow = True,
                                    explode = (0,0.1,0.2))

for t in texts:
  t.set_fontsize(12)
  t.set_color('gray')

for t in autotexts:
  t.set_color('white')
  t.set_fontsize(18)
    
    
ax[0].set_title('HongKong Review Sentiment Analysis')







sizes2 = [17632/len(df_California['Analysis']), 1531/len(df_California['Analysis']), 243/len(df_California['Analysis'])]
labels2 = ['Positive', 'Negative', 'Neutral']

pathes, texts, autotexts = ax[1].pie(sizes2, 
                                    labels = labels2,
                                    autopct = '%1.1f%%',
                                    shadow = True,
                                    explode = (0,0.1,0.2))

ax[1].set_title('California Sentiment Analysis')




sizes3 = [12030/len(df_Paris['Analysis']), 1514/len(df_Paris['Analysis']), 86/len(df_Paris['Analysis'])]
labels3 = ['Positive', 'Negative', 'Neutral']

pathes, texts, autotexts = ax[2].pie(sizes3, 
                                    labels = labels3,
                                    autopct = '%1.1f%%',
                                    shadow = True,
                                    explode = (0,0.1,0.2))

ax[2].set_title('Paris Sentiment Analysis')
# Out:
# Text(0.5, 1.0, 'Paris Sentiment Analysis')

# %%
N_HK = df[(df['Branch']=='Disneyland_HongKong') & (df['Analysis']=='Negative')]
N_HK
# Out:
#       Rating Reviewer_Location  \
# 5          3         Singapore
# 8          2         Australia
# 10         5     United States
# 15         3    United Kingdom
# 17         3    United Kingdom
# ...      ...               ...
# 9592       3    United Kingdom
# 9604       1     United States
# 9608       1         Singapore
# 9611       4     United States
# 9615       1     United States
#
#                                             Review_Text               Branch  \
# 5     [disney, world, disneyland, anaheim, tokyo, di...  Disneyland_HongKong
# 8     [feel, let, placethe, disneyland, train, fanta...  Disneyland_HongKong
# 10    [disneyland, never, cease, amaze, ive, disneyl...  Disneyland_HongKong
# 15    [brought, tickets, left, got, 2, days, less, p...  Disneyland_HongKong
# 17    [around, , 60, per, person, want, eat, drink, ...  Disneyland_HongKong
# ...                                                 ...                  ...
# 9592  [hong, kong, 5, weeks, disney, fans, disney, p...  Disneyland_HongKong
# 9604  [hk, disney, boring, , go, ocean, park, , go, ...  Disneyland_HongKong
# 9608  [waste, time, money, think, planning, bringing...  Disneyland_HongKong
# 9611  [spent, christmas, eva, park, 1130am, 830pm, ,...  Disneyland_HongKong
# 9615  [husband, took, 2, kids, worst, experience, li...  Disneyland_HongKong
#
#       Polarity  Analysis
# 5    -0.100000  Negative
# 8    -0.064286  Negative
# 10   -0.050000  Negative
# 15   -0.052500  Negative
# 17   -0.076871  Negative
# ...        ...       ...
# 9592 -0.003630  Negative
# 9604 -1.000000  Negative
# 9608 -0.125036  Negative
# 9611 -0.466667  Negative
# 9615 -0.043169  Negative
#
# [768 rows x 6 columns]

# %%
N_HK['Review_Text']
# Out:
# 5       [disney, world, disneyland, anaheim, tokyo, di...
# 8       [feel, let, placethe, disneyland, train, fanta...
# 10      [disneyland, never, cease, amaze, ive, disneyl...
# 15      [brought, tickets, left, got, 2, days, less, p...
# 17      [around, , 60, per, person, want, eat, drink, ...
#                               ...
# 9592    [hong, kong, 5, weeks, disney, fans, disney, p...
# 9604    [hk, disney, boring, , go, ocean, park, , go, ...
# 9608    [waste, time, money, think, planning, bringing...
# 9611    [spent, christmas, eva, park, 1130am, 830pm, ,...
# 9615    [husband, took, 2, kids, worst, experience, li...
# Name: Review_Text, Length: 768, dtype: object

# %%
for i in N_HK['Review_Text']:
    print(i)
# Out:
# ['disney', 'world', 'disneyland', 'anaheim', 'tokyo', 'disneyland', 'feel', 'disneyland', 'hong', 'kong', 'really', 'small', 'called', 'disneyland', 'way', 'rides', 'attractions', 'souvenirs', 'food', 'even', 'entrance', 'tickets', 'slightly', 'expensive', 'disneyland', 'well', 'basically', 'park', 'good', 'small', 'children', 'people', 'never', 'disney', 'food', 'choices', 'acceptable', 'mostly', 'fast', 'food', 'expensive', 'bottled', 'water', 'however', 'expensive', 'water', 'fountains', 'around', 'refill', 'water', 'bottles', 'parade', 'pretty', 'good', 'crowded', 'problem', 'problem', 'people', 'rude', 'pushing', 'shoving', 'cutting', 'lines', 'rides', 'gift', 'shops', 'food', 'stands', 'much', 'take', 'forget', 'trying', 'see', 'one', 'shows', 'free', 'seats', 'dont', 'see', 'disney', 'let', 'happen', 'far', 'worst', 'managed', 'disney', 'property']
# ['feel', 'let', 'placethe', 'disneyland', 'train', 'fantastic', 'get', 'past', 'stationbad', 'signage', 'terrible', 'staff', 'want', 'rainning', 'rides', 'working', 'could', 'find', 'map', 'place', 'priced', 'fun', 'park', 'disney', 'characters', '2', 'seen', 'cabana', 'photos', 'visitors', 'queuing', 'rain', 'dont', 'waste', 'money', 'walt', 'disney', 'would', 'horrified', 'enough', 'eating', 'places', 'amount', 'people', 'rest', 'rooms', 'seems', 'building', 'something', 'knows', 'atmosphere', 'fun', 'fantasy']
# ['disneyland', 'never', 'cease', 'amaze', 'ive', 'disneyland', 'florida', 'thought', 'exhausted', 'kid', 'nope', 'still', 'much', 'fun', 'disneyland', 'hong', 'kong', '2', 'dl', 'bucketlist', 'come', '']
# ['brought', 'tickets', 'left', 'got', '2', 'days', 'less', 'price', '1', 'visiting', 'would', 'advise', 'everyone', 'look', 'online', 'deal', 'worth', 'walk', 'price', 'castle', 'closed', 'due', 'area', 'refurbished', 'altered', 'weekday', 'aprox', '30', 'min', 'wait', 'rides', 'less', 'would', 'recommend', 'weekends', 'holidays', 'said', 'like', 'disney', 'parks', 'theme', 'parks', 'general', 'food', 'drink', 'expensive', 'small', 'park', 'easily', 'done', '1', 'day']
# ['around', '', '60', 'per', 'person', 'want', 'eat', 'drink', 'point', 'cost', 'small', 'fortune', 'go', 'week', 'day', 'like', 'assume', 'like', 'us', 'wait', 'around', 'half', 'hour', 'per', 'ride', 'time', 'went', 'disney', 'castle', 'construction', 'doesnt', 'look', 'like', 'finished', 'soon', 'fast', 'track', 'free', 'everyone', 'single', 'rider', 'lot', 'faster', 'average', 'day', 'expensive', 'place']
# ['visited', 'wednesday', 'arrived', 'opening', 'found', 'queue', 'times', 'short', 'done', 'rides', 'wanted', 'early', 'afternoon', 'unfortunately', 'fireworks', 'due', 'castle', 'renovated', 'seen', 'many', 'parades', 'disney', 'world', 'decided', 'stay', 'evening']
# ['need', 'say', '', 'home', 'disney', '', 'disneyland', 'anaheim', 'hk', 'disney', '8th', 'park', '', 'biggest', 'ride', '', 'scary', 'space', 'mountain', 'mostly', 'kiddy', 'rides', 'really', 'enjoy', 'lion', 'king', 'show', '', 'get', 'expensive', 'water', 'equates', '6', 'aud', 'small', 'bottle', 'burger', 'combo', 'meal', 'equated', '22', 'aud', 'also', 'stayed', 'disney', 'hollywood', 'hotel', '', 'u', 'balls', 'charge', 'insane', 'prices', '120', 'aud', 'buffet', 'dinner', '55', 'aud', 'breakfast', 'shops', '', 'cafes', '', 'supermarkets', 'nearby', 'grab', 'snack', 'cheap', 'dinner', 'unless', 'u', 'take', '2', 'trains', 'travelling', 'thru', 'hk', '', 'china', '3', 'weeks', 'crazy', 'expensive', 'crappy', 'deep', 'fried', 'food', 'flavourless', 'bowl', 'lettuce', 'salad', 'food', 'places', 'open', 'castle', 'maintenance', 'train', 'maintenance', 'vouchers', 'got', 'way', 'stating', 'shops', 'main', 'st', '10', 'discount', '1030', 'told', 'bakery', '', '', '', 'home', '', 'called', 'false', 'advertising', 'toy', 'story', 'land', 'insanely', 'hot', '', 'shade', 'sun', 'bouncing', 'light', 'concrete', '', 'husband', 'actually', 'hypo', 'waiting', 'daughter', 'ride', 'coz', '', 'hot', 'come', 'disneyland', 'surely', 'put', '', 'camo', 'style', 'shades', '', 'waiting', 'parents', '', 'pass', 'seats', 'elderly', '', 'go', 'astray', 'either', 'pretty', 'disappointing', 'experience', '900', 'aud', 'poorer', '2', 'adults', '', '1', 'child', '2', 'day', 'pass', 'note', 'u', '', 'need', 'go', 'back', 'second', 'day']
# ['recent', 'stop', 'hong', 'kong', 'paid', 'return', 'trip', 'disney', 'chose', 'day', 'park', 'quiet', 'longest', 'wait', '30', 'minutes', 'sure', 'case', 'timesunfortunately', 'rides', 'tested', 'upgraded', 'prevent', 'disappointment', 'check', 'closures', 'gowe', '', 'eat', 'park', 'previous', 'experience', '', 'restaurant', 'disappointing', 'expensivethis', 'third', 'visit', 'park', 'whenever', 'visit', 'hong', 'kong', 'visit', 'disney', 'must']
# ['impromptu', 'trip', 'disneyland', 'weekday', 'love', 'trip', 'wait', 'time', 'least', '15minutes', 'wait', 'time', 'rides', 'limited', 'restaurants', 'though', 'maybe', '', 'weekday', 'bad', 'part', 'though', 'castle', 'renovation', 'going', 'construction', 'park']
# ['', 'feel', 'disney', 'spirit', 'place', 'disney', 'characters', 'around', 'one', 'must', 'wait', 'long', 'lineup', 'shake', 'hand', 'stayed', 'couple', 'hours', 'left']
# ['optimal', 'size', 'try', 'rides', 'one', 'day', 'queue', 'less', '30', 'minutes', 'wish', 'affordable', 'gifts', 'shops', 'food', 'beverages']
# ['ive', 'seen', 'many', 'negative', 'posts', 'comments', 'hk', 'disneyland', 'past', 'really', 'bad', 'yes', 'expensive', 'small', 'tons', 'rides', 'agesas', 'hk', 'resident', 'always', 'go', 'hk', 'disneyland', 'experience', 'every', 'time', 'whether', 'parade', 'rides', 'park', 'incredible', 'tons', 'revamps', 'past', 'years', 'farewells', 'autopia', 'buzz', 'lightyear', 'astroblasters', 'replaced', 'brand', 'new', 'section', 'tomorrowland', 'featuring', 'iron', 'man', 'ant', 'man', 'coming', 'april', 'well', 'brand', 'new', 'revamp', 'space', 'mountain', 'staff', 'extremely', 'helpful', 'gift', 'shops', 'loads', 'merchandise', 'souvenirs', 'park', 'also', 'extremely', 'kid', 'friendly', 'negative', 'extract', 'park', 'food', 'price', 'food', 'isnt', 'bad', 'quality', 'way', 'expensive', 'since', 'visitors', 'arent', 'allowed', 'bring', 'food', 'might', 'starve', 'day', 'buy', 'expensive', 'mealif', 'lots', 'free', 'time', 'hk', 'want', 'something', 'enjoyable', 'whether', 'kids', 'mates', 'hk', 'disney', 'great', 'park', 'although', 'major', 'thrill', 'seeker', 'ocean', 'park', 'would', 'suited']
# ['small', 'disappointing', 'along', 'line', 'park', 'small', 'without', 'big', 'attractions', '3', 'hours', 'seen', 'everything', 'construction', 'lot', 'noise', 'visit', 'ridiculous', 'visit', 'enchanted', 'forest', 'heard', 'jackhammer', 'maneges', 'limited', 'prices', 'high', 'quality', 'park', 'better', 'keep', 'money', 'invest', 'another', 'activity']
# ['came', 'parents', 'years', 'ago', 'came', 'another', 'visit', 'rides', 'okay', 'usual', 'super', 'crowded', 'busy', 'especially', 'lunch', 'hours', 'queue', 'long', '45', 'mins', 'hour', 'food', 'especially', 'starliner', 'restaurant', 'serves', 'western', 'food', 'ticket', 'came', 'food', 'coupon', 'purchase', 'meal', '149hk', 'bought', 'recommended', 'value', 'set', 'maximise', 'burger', 'pathetic', 'small', 'flat', 'meat', 'half']
# ['visited', 'disneyland', 'hong', 'kong', 'today', 'march', '15', '2019', 'poor', 'experience', 'little', 'first', 'place', 'terms', 'rides', 'experiences', 'closed', 'renovations', 'including', 'main', 'disney', 'castle', 'lots', 'stuff', 'open', 'anyway', 'kids', 'couldnt', 'get', 'pics', 'fav', 'characters', 'kept', 'disappearing', 'break', 'every', '20', 'mins', 'queues', 'long', 'already', 'missing', 'even', 'reduction', 'already', 'expensive', 'price', 'pretty', 'crappy', 'day', 'outsmall', 'park', 'half', 'open', 'worth', 'money']
# ['interesting', 'park', 'although', 'crowded', 'line', 'ups', 'never', 'bad', 'went', 'plan', 'one', 'day', 'enjoy', 'suggest', 'going', 'shopping', 'early', 'day', 'people', 'savages', 'store', 'workers', 'couldnt', 'even', 'keep', 'people', 'throwing', 'things', 'floor', 'shelves', 'mess', 'terrible', 'store', 'experience', 'waited', '45', 'mins', 'pay', 'park', 'fun', '', 'space', 'mountian', 'fantastic', 'shopping', 'awful', 'know', 'going', '', 'need', 'one', 'day', 'park']
# ['ive', 'gone', 'disney', 'parks', 'california', 'orlando', 'hk', 'disneyland', 'small', 'comparison', 'loved', 'park', 'wont', 'exhausted', 'end', 'day', 'still', 'allow', 'activities', 'youve', 'finished', 'time', 'scheduled', 'time', 'friend', '11', 'met', 'friend', 'nam', 'cheong', 'mtr', 'rode', 'disneyland', 'line', 'smart', 'thing', 'would', 'buy', 'tickets', 'phone', 'riding', 'mtr', 'didnt', 'wasted', 'time', 'ticket', 'gateonce', 'took', 'rounds', 'pictures', 'first', 'impression', '', 'wow', 'thats', 'castle', 'awful', '', 'though', 'blocked', 'castle', 'making', 'robust', 'castle', 'soon', 'im', 'understandingin', 'parks', 'like', 'japan', 'usa', 'looking', 'snacks', 'around', 'park', 'heres', 'looking', 'dole', 'whip', 'need', 'get', 'way', 'food', 'awful', 'hk', 'disney', 'fact', 'really', 'surprised', 'given', 'theres', 'much', 'good', 'food', 'hk', 'really', 'pretty', 'horrid', 'friend', 'bad', 'lunch', 'went', 'along', 'rides', 'rides', '20', 'minute', 'wait', 'thought', 'acceptable', 'think', 'longest', 'wait', 'hyperspace', 'mountain', '40', 'minuteschecked', 'parade', 'actually', 'hoping', 'asian', 'women', 'dressed', 'cinderella', 'snow', 'white', 'nope', 'god', 'forbid', 'snow', 'white', 'asian', 'suppose', 'get', 'lolafter', 'snack', 'fails', 'philharmagic', '3d', 'show', 'exited', 'park', 'around', '6', 'pm', 'took', 'mtr', 'straight', 'tsim', 'sha', 'tsui', 'nice', 'dinner', '7', 'pm', '9', 'pm', 'friends', 'parked', 'whisky', 'bar', '1130', 'pm', 'home', 'bedit', 'one', 'amazing', 'days', 'type', 'disney', 'excursion', 'never', 'happens', 'either', 'california', 'florida', 'simply', 'give', 'scale', 'parks', 'also', 'awful', 'public', 'transportation', 'either', 'citiesi', 'wouldnt', 'recommend', 'coming', 'hk', 'disneyland', 'would', 'let', 'however', 'youre', 'sightseeing', 'hk', 'time', 'disney', 'brainer', 'go']
# ['every', 'year', 'come', 'disney', 'children', 'every', 'year', 'worse', 'last', 'oneprices', 'entrance', 'tickets', 'outrageous', 'specially', 'taking', 'account', 'rides', 'minimalfood', 'prices', 'normal', 'even', 'disney', 'super', 'hyper', 'expensive', 'horrible', 'food', 'even', 'junk', 'food', 'tastelessonly', 'good', 'thing', 'place', 'leaving']
# ['didnt', 'like', 'unhelpfulness', 'staff', 'pre', 'purchased', 'meal', 'vouchers', 'lost', 'soon', 'entering', 'park', 'went', 'back', 'one', 'stores', 'check', 'dropped', 'paying', 'merchandise', 'store', 'lady', 'rude', 'rudely', 'asked', 'bow', 'know', 'even', 'find', 'asked', 'many', 'people', 'come', 'looking', 'food', 'vouchers', 'said', 'none', 'couldnt', 'believe', 'crass', 'people', 'requested', 'reception', 'reprint', 'voucher', 'since', 'bar', 'code', 'refused', 'saying', 'cant', 'shows', 'backward', 'technology', 'big', 'deal', 'reprint', 'bar', 'code', 'someone', 'already', 'used', 'voucher', 'bar', 'code', 'wouldnt', 'work', 'anyway', 'harm', 'reprinting', 'itwe', 'christmas', 'holidays', 'crowded', 'well', 'organised', 'places', 'closed', 'since', 'expanding', 'parade', 'fun', 'ride', 'especially', 'star', 'wars', 'grizzly', 'gulch']
# ['bought', 'ticket', 'klook', 'easily', 'access', 'disneyland', 'entrance', 'print', 'document', 'present', 'staff', 'entrancesome', 'bad', 'things', 'present', 'cartoon', 'waited', 'take', 'picture', 'donald', 'duck', 'daisy', 'showed', 'short', 'time', 'waste', 'time', 'lot', 'woody', 'toy', 'story', 'showed', 'morning', 'almost', 'cried', 'staff', 'told', 'woody', 'show', 'parade', 'time', 'eveninglong', 'queue', 'wait', 'machine', 'wait', 'around', '40', 'minutes', '1', 'hour', 'play', '5', 'minutesfood', 'disneyland', 'really', 'good', 'choice', 'eat']
# ['always', 'wanted', 'see', 'disneyland', 'chance', 'christmas', 'eve', '2018', 'disappointed', 'maybe', '7', 'nearly', '70', 'might', 'enjoyed', 'expected', 'see', 'lot', 'characters', 'confronted', 'closed', 'exhibits']
# ['', 'experience', 'visit', '600', 'hk', '', 'every', 'things', 'crazy', '', 'waiting', 'time', 'ride', 'well', 'one', 'hours', '', 'washroom', 'closed', 'one', 'half', 'hours', 'wait', 'poor', 'ladies', '1the', 'foods', 'pricey', 'ever', 'micky', 'would', 'buy', 'people', 'people', 'people', '', 'small', 'kingdom', 'local', 'want', 'come', 'wonder', 'lost', 'money', 'every', 'year', 'better', 'save', 'time', 'moneys', 'things', 'else', 'thank', '']
# ['tad', 'disappointing', 'paris', 'disney', 'small', 'fun', 'rides', 'disappointing', 'lack', 'variety', 'retail', 'therapy', 'sorry', 'disney', '', 'go', 'ocean', 'park', 'next', 'time']
# ['good', 'day', 'tired', 'kids', 'unfortunately', 'time', 'much', 'due', 'queues', 'waiting', 'around', '', 'done', 'probably', 'would', 'choose', 'go', 'back', 'especially', 'prices']
# ['visited', 'australia', 'enjoyed', 'rides', 'parades', 'shows', 'disappointed', 'toy', 'train', 'ride', 'closed', 'knew', 'castle', 'would', 'renovation', 'biggest', 'let', 'leaving', 'decided', 'pop', 'gift', 'shop', 'buy', 'mickey', 'mini', 'mouse', 'plush', 'toy', 'chinese', 'outfits', 'sign', 'said', '2', 'hkd298', 'went', 'pay', 'girl', 'behind', 'counter', 'said', 'hkd168', 'took', 'colleague', 'show', 'offer', 'sign', 'said', '', 'apply', 'mickey', 'mini', 'plush', 'toys', 'duffy', 'friends', 'toys', 'girl', 'condescending', 'made', 'us', 'feel', 'unpleasant', 'accepted', 'bought', 'hkd336', 'left', 'hong', 'kong', 'airport', '2', 'days', 'later', 'disney', 'store', 'airport', '', 'know', 'would', 'one', 'saw', 'deal', '2', 'plush', 'hkd298', 'asked', 'applied', 'mickey', 'mini', 'mouse', 'lo', 'behold', 'girl', 'store', 'said', '2', 'hkd298', 'disneyland', 'park', 'store', 'honour', 'offer', 'store', 'disappointed', 'staff', 'rude', 'tried', 'enquire', 'offer', 'rightly', 'given', 'everyone', 'airport', 'store', 'give', 'us', 'offer', 'clearly', 'stated', 'stand', 'main', 'disneyland', 'made', 'would', 'great', 'day', 'disneyland', 'unpleasant', 'discouraged', 'family', '', 'friends', 'visit', 'hong', 'kong', 'disneyland', 'due', 'unpleasant', 'experience', 'disney', 'would', 'like', 'honest', 'promotions', 'honour', 'stated', 'pricing']
# ['3', 'years', 'ago', 'park', 'slight', 'change', 'time', 'firework', 'night', 'parade', 'disney', 'characters', 'looking', 'halal', 'food', 'place', 'adventure', 'land', 'serve', 'asian', 'food', 'quite', 'resonable', 'price', 'ride', 'please', 'go', 'iron', 'man', 'ride', '3d', 'also', 'go', 'star', 'war', 'jedi', 'training', 'fight', 'darth', 'vader', 'starwar', 'fan', 'must', 'miss', 'every', 'ride', 'waiting', 'time', '20', 'minutes', 'overall', 'park', 'well', 'organise']
# ['two', 'rides', 'lands', 'areas', 'several', 'rides', 'closed', 'park', 'small', 'rides', 'compacted', 'small', 'spaces', 'rides', 'short', 'best', 'show', 'lion', 'king', 'moana', 'disappointing', 'lines', '15', '30', 'minutes', 'waiting', 'time', '80', 'get', 'cooked', 'squid', 'sell', 'kiosks', 'tastes', 'like', 'beef', 'jerky', 'take', 'subway', 'get', 'disneyland']
# ['', 'disney', 'abre', 'time', 'specially', 'visiting', 'children', '', 'visited', 'disneyland', 'california', 'disney', 'world', 'florida', '', 'disappointed', 'like', 'disney', '', 'pretty', 'way', 'far', 'complicated', 'get', 'expensive', 'small', 'attractions', 'oldest', 'classics', 'park', 'like', 'jungle', 'river', 'cruise', 'dumbo', '', 'small', 'world', 'etc']
# ['would', 'spend', 'money', 'going', 'america', 'could', 'go', 'hong', 'kong', 'disneyland', 'carefree', 'trip', 'train', 'arriving', 'late', 'morning', 'saw', 'lion', 'king', 'show', 'went', 'rides', 'watched', '', 'halloween', 'parade', '', 'ate', 'drank', 'ball', 'didnt', 'leave', 'nightfall', 'highly', 'recommended']
# ['park', '2', 'days', 'jan', 'weekdays', 'park', 'crowded', 'rides', 'waiting', 'time', 'less', '30', 'mins', 'weather', 'great', 'well', 'however', 'fireworks', 'end', 'parade', 'weekday', 'disappointing']
# ['6th', 'visit', 'hk', 'disneyland', 'everything', 'close', 'proximity', 'queues', '', 'bad', '', '30', 'minutes', 'tops', 'bad', 'new', 'year', '', 'day', 'still', 'shame', 'fireworks', 'knowing', 'beforehand', 'booked', 'dinner', 'would', 'normally', 'watch', 'fireworks', 'display']
# ['place', 'overrated', 'entrance', 'fees', 'expensive', 'queues', 'rides', 'long', 'crowd', 'horrible', 'tokyo', 'disneyland', 'much', 'better', 'btw', 'ocean', 'park', 'way', 'better']
# ['compare', 'universal', 'studios', 'disneyland', 'hongkong', 'overrated', '1', 'tickets', 'expensive', 'half', 'theme', 'park', 'renovation', '2', 'food', 'way', 'expensive', 'quality', 'product', 'least', 'upgrade', 'taste', 'serving', 'course', 'presentation', '3', 'photo', 'ops', 'mascots', '15', 'minutes', 'additional', 'time', 'atleast', 'post', 'timeline', 'map', 'direction', 'visitor', '', 'reference', '4', 'sellers', 'rude', 'give', 'unless', 'pay', 'first', '', 'going', 'pay', 'order', 'duh', '', '5', 'good', 'kids', '', 'like', 'extreme', 'rides', '6', 'picture', 'maze', 'imposed', 'limited', 'time', 'also', 'recommend', 'children', 'teens', 'enjoy', 'extreme', 'rides', '7', 'food', 'drinks', 'outside', 'prohibited', 'food', 'awesomely', 'tasteful', '', 'really', 'waste', 'money', 'eat', 'quality', 'rather', 'pricy']
# ['two', 'day', 'visit', 'disneyland', 'bitter', 'disappointment', 'park', 'busy', 'could', 'move', 'around', 'freely', 'average', 'wait', 'time', 'ride', '60', 'minutes', 'option', 'fast', 'pass', 'norm', 'many', 'theme', 'parks', 'around', 'world', 'see', 'disney', 'princesses', 'photo', 'opportunity', 'reason', 'youngest', 'two', 'wanted', 'go', 'disneyland', 'photo', 'opportunities', 'full', 'even', 'arrived', 'destination', 'train', 'around', 'park', 'went', 'one', 'way', 'return', 'point', 'departure', 'lines', 'coffee', 'food', 'resulted', 'leaving', 'park', 'earlier', 'anticipated', 'wait', 'long', 'disappointing', 'experience', 'say', 'least', 'back', 'please', 'visit', 'christmas', 'new', 'year', 'season']
# ['say', 'must', 'visit', 'location', 'hk', 'kids', 'adults', 'also', 'enjoy', 'fullest', 'well', 'maintained', 'rides', 'houses', 'lot', 'theme', 'parks', 'within', '', 'small', 'world', '', 'must', 'watch', 'show', 'donot', 'come', 'back', 'without', 'watching', 'parade', 'fireworks']
# ['went', 'december', '12', 'weather', 'cold', 'crowded', 'unfortunately', 'planning', 'visit', 'sleeping', 'beauty', 'castle', 'youll', 'disappointed', 'renovation', 'theres', 'also', 'fireworks', 'also', 'visited', 'jungle', 'river', 'cruise', 'unavailable', 'kids', 'love', 'place', 'lot', 'constructions', 'going']
# ['pain', 'expensive', 'cheesy', 'touristic', 'rip', 'one', 'centre', 'felt', 'like', 'entire', 'life', '', 'savings', 'squeezed', 'ok', 'kids', 'even', 'got', 'bored', 'stuff', 'quickly', 'needs', 'rethinking']
# ['like', 'disneylands', 'hong', 'kong', 'quite', 'small', 'monday', 'still', 'quite', 'crowded']
# ['first', 'visit', 'hong', 'kong', 'disneyland', 'impressions', 'biased', 'towards', 'tokyo', 'disneyland', 'prior', 'hk', 'disneyland', 'apart', 'rather', 'small', 'sleeping', 'beauty', 'castle', 'renovation', 'stood', 'small', 'park', 'expensive', 'food', 'yet', 'peak', 'visitation', 'helped', 'slightly', 'rainy', 'weather', 'also', 'ruined', 'outdoor', 'shows', 'parades', 'managed', 'cover', 'rides', 'shows', 'wanted', 'day', 'attractions', 'liked', 'festival', 'lion', 'king', 'mickey', 'wonderous', 'book', 'iron', 'man', 'experience', 'mickey', '', 'philharmagic']
# ['arrived', 'castle', 'closed', 'rides', 'operating', 'still', 'pay', 'full', 'price', 'ate', 'meal', 'absolutely', 'tasteless', 'fact', 'worst', 'meal', 'yearswe', 'ordered', 'shabu', 'shabu', 'japanese', 'outlet', 'wanted', 'order', 'fish', '', 'chips', 'somewhere', 'near', 'goldmine', 'restaurant', 'closedcorn', 'cob', 'us6', 'ice', 'cream', 'terribly', 'expensive', 'wife', 'enjoyed', 'visiting', 'disneyland', 'seeing', 'couple', 'parades', 'couple', 'shows', 'many', 'photos', 'would', 'enjoyable', 'children', 'sure', 'would', 'cost', 'lot', 'would', 'wanting', 'ice', 'cream', 'toys', 'pop', 'corn', 'drinks', 'etc', 'would', 'prepared', 'pay', 'ridiculous', 'prices']
# ['disneyland', 'disneyland', 'one', '', 'recommend', 'going', 'visit', 'kids', 'yes', 'overpriced', 'little', 'boring', 'honest']
# ['full', 'mainland', 'tourists', 'spitting', 'pushing', 'shoving', 'happiest', 'place', 'earth', 'expensive']
# ['spent', 'weekend', 'hk', 'daughter', '', 'gymnastics', 'meet', 'decided', 'reward', 'afterwards', 'family', 'day', 'disneyland', 'great', 'fun', 'especially', 'since', 'joined', 'friends', 'event', 'daughters', 'cartwheeled', 'way', 'entrance', 'crowd', '', 'bad', 'castle', 'repair', 'traditional', 'fireworks', 'cap', 'night', 'instead', 'light', 'show', 'parade', '', 'half', 'bad']
# ['awesome', 'went', 'monday', 'got', 'see', 'every', 'show', 'ride', 'every', 'ride', 'wanted', 'wait', 'times', 'minimal', 'crowds', 'sparse', 'would', 'say', 'one', 'poor', 'experience', 'came', 'cast', 'member', 'responsible', 'maintaining', 'line', 'pluto', 'meet', 'greet', 'quite', 'rude', 'yelled', 'children', 'repeatedly', 'yelled', 'parents', 'child', 'parent', 'got', 'line', 'allowed', 'rejoin', 'line', 'ahead', 'son', 'also', 'frustrating', 'waiting', 'quite', 'time', 'see', 'pluto', 'didnt', 'find', 'overly', 'expensive', 'disney']
# ['visited', 'theme', 'park', '4', 'times', 'past', 'years', 'getting', 'old', 'shows', 'time', 'give', 'place', 'spruce', '', 'add', 'new', 'rides', 'otherwise', 'lose', 'visitors', 'theme', 'parks', 'region']
# ['dumb', 'goamerica', 'street', 'boring', 'place', 'prices', 'aint', 'cheap', 'much', 'bought', 'elsewherethe', 'zones', 'horriblewith', 'much', 'people', 'staff', 'much', 'adventurevery', 'unhappy', 'whole', 'trip']
# ['visit', '5th', 'nov', 'sadly', 'alot', 'rides', 'attraction', 'close', '', 'besides', 'place', 'clean', 'well', 'kept']
# ['visited', 'disneyland', 'paris', '25', 'years', 'ago', 'decided', 'spend', 'last', 'day', 'holiday', 'disneyland', 'hong', 'kong', 'rides', 'outdated', 'given', 'hk', 'love', 'things', 'electronic', 'expected', 'greater', 'variety', 'rides', 'paris', 'parades', 'started', 'late', '', 'missed', 'last', 'minutes', 'evening', 'parade', 'coach', 'pick', 'meet', 'parades', 'patch', 'paris', '25', 'years', 'agothe', 'majority', 'staff', 'rude', 'unhelpful', '', 'unlike', 'paris', 'staff', 'given', 'english', 'widely', 'spoken', 'hk', 'lot', 'staff', 'barely', 'understood', 'english', 'putting', 'mildly', 'utter', 'disappointment', 'start', 'finish']
# ['time', 'visit', 'partial', 'closure', 'park', 'due', 'private', 'event', '2nd', '3rd', 'november', 'came', 'way', 'indonesia', 'paying', 'expensive', 'airfares', 'also', 'paying', 'expensively', '2', 'night', 'stay', 'hotel', 'visit', 'several', 'sections', 'adventureland', 'grizzly', 'gulch', 'mystic', 'point', 'toy', 'story', 'landto', 'make', 'matters', 'worse', 'closure', 'done', 'prime', 'time', 'park', 'around', '2', '3', 'pm', 'way', 'dark', 'around', '6', 'pm', 'cases', 'even', 'disney', 'closed', 'disappointed', 'would', 'like', 'see', 'responsibilities', 'disney', 'regarding', 'issue', 'disney', 'shouldve', 'given', 'certain', 'reduction', 'hotel', 'price', 'day', 'pass', 'price', 'due', '', 'incomplete', 'magical', 'experience', '']
# ['extremely', 'average', 'rides', 'please', 'save', 'money', 'go', 'universal', 'studios', 'singapore', '', 'get', 'anywhere', 'close', 'creating', 'magical', 'experiences', 'promise', 'park', 'crowded', 'sections', 'shut', 'renovations', 'paying', 'entry', 'seemed', 'like', 'eternally', 'queue', 'rides', 'exhibits', 'extremely', 'disappointing']
# ['disneyland', 'one', 'major', 'attractions', 'tourists', 'visiting', 'hongkonghowever', 'expensive', 'apart', 'heaven', 'kids']
# ['cant', 'go', 'wrong', 'disneyland', 'kids', 'suggest', 'go', 'early', 'avoid', 'long', 'lines', 'afternoon', 'lines', 'rides', 'starts', 'build', 'waiting', 'time', '20', '40mins', 'unlike', 'morning', '5', '10mins']
# ['quite', 'disappointed', 'castle', 'renovation', 'hence', 'fireworks', 'characters', 'roaming', 'around', 'park', 'limited', 'street', 'march', 'ended', 'fast']
# ['small', 'park', '', 'feel', 'like', 'disney', 'lion', 'king', 'show', 'cancelled', 'park', 'attendees', 'booked', 'private', 'part', 'day', 'unfair', 'thought', 'restaurants', 'closed', 'castle', 'building', 'site', 'poor', 'considering', 'still', 'payed', 'full', 'price', 'mentioned', 'disney', 'customer', 'services', 'brushed', 'reply', 'checked', 'web', 'site', 'day', 'closures', 'bit', 'crap', 'bought', 'ticket', '2', 'months', 'earlier', '', 'returning', 'really', 'poor', 'excuse', 'disneyland']
# ['much', 'smaller', 'california', 'disneyland', 'almost', 'identical', 'respects', '', 'covered', 'easily', 'half', 'day']
# ['comes', 'disney', 'expect', 'wonderful', 'things', 'disappointed', 'overall', 'experience', 'recent', 'visit', 'park', 'small', 'doesnt', 'magical', 'vibe', 'anaheim', 'disneyland', 'exhibits', 'majority', 'staff', 'encountered', 'personalities', 'bricks', 'showed', 'happiness', 'excitement', 'food', 'options', 'average', 'opportunities', 'photos', 'characters', 'limited', 'park', 'closing', 'approx', '845pm', 'day', 'visited', 'photos', 'mickey', 'minnie', 'closed', '4pm', 'causing', 'much', 'disappointment', 'numerous', 'visitors', 'general', 'upkeep', 'park', 'also', 'seemed', 'quite', 'poor', 'overgrown', 'gardens', 'dirty', 'grounds', 'areas', 'advantage', 'much', 'shorter', 'queues', 'rides', 'disneyland', 'feels', 'like', 'another', 'average', 'theme', 'park', 'doesnt', 'even', 'come', 'close', 'comparing', 'original', 'anaheim', 'wouldnt', 'recommend', 'visiting', 'theme', 'park']
# ['would', 'expect', 'disney', 'site', 'queues', 'short', 'day', 'meant', 'saw', '', 'rode', 'attractions', 'one', 'day', 'reason', 'giving', '5', 'stars', 'area', 'park', 'close', '7pm', 'two', 'attractions', 'closed', '5pm', 'could', 'visit']
# ['planned', 'trip', 'hong', 'kong', 'didnt', 'realise', 'would', 'mid', 'autumn', 'festival', 'went', 'disneyland', 'sunday', 'festival', 'didnt', 'realise', 'line', 'get', 'park', 'would', 'hour', 'long', '10am', 'heat', 'oppressive', 'far', 'little', 'shade', 'water', 'dispensers', 'available', 'waiting', 'waiting', 'waiting', 'gave', '3pm', 'getting', '11am', 'leftthe', 'park', 'small', 'compared', 'disneylands', 'crowds', 'bag', 'check', 'entrance', 'like', 'never', 'ever', 'seen', 'crazy']
# ['go', 'never', 'disneyland', 'one', 'people', 'crazy', 'disney', '', 'small', 'really', 'small', 'whole', 'park', 'half', 'day', '', 'go', 'chinese', 'holiday', 'flooded', 'mainland', 'chinese', 'tourists', 'pretty', 'much', 'every', 'disneyland', '10', 'size', 'take', 'advantage', 'fast', 'pass', 'system', 'ticket', 'crumpled', 'broken', 'machine', '', 'accept', 'small', 'inconspicuous', 'button', 'back', 'fastpass', 'machine', 'print', 'fast', 'pass', 'ticket', 'unscrupulous', 'visitors', 'press', 'repeatedly', 'get', 'multiple', 'rides', 'without', 'waiting', 'line', 'visit', 'rides', '', 'fast', 'pass', 'first', 'last', 'thing', 'stay', 'late', 'fireworks', 'castle']
# ['goodmtr', 'make', 'approachablegood', 'staff', 'buy', 'ticket', 'onlineor', 'contact', 'hotel', 'one', 'day', 'enough', 'atlest', 'children', 'food', 'horrible', 'vegetarians']
# ['tokyo', 'la', 'disneylandi', 'also', 'visited', 'disneyland', 'back', '2006back', '2006', 'disappointed', 'small', '12', 'years', 'well', 'truly', 'expandedonly', 'thing', 'missing', 'toon', 'town', 'great', 'day', '2', 'people', 'young', 'children', '122', 'day', 'pass', 'around', '400', 'aud', '2', 'adults', '2', 'kidsworth', 'visit', 'never', 'beforesuggest', 'train']
# ['visited', '09', '20', 'humid', 'day', 'ducked', 'shops', 'cool', 'week', 'day', 'crowded', 'recovered', 'typhoon', 'rather', 'quickly', 'everything', 'open', 'would', 'never', 'know', 'typhoon', 'passed', 'ironman', 'experience', 'cheesy', 'photo', 'opportunity', 'person', 'ironman', 'costume', 'used', 'pre', 'recorded', 'voice', 'moana', 'homecoming', 'celebration', 'outdoors', 'half', 'covered', 'venue', 'also', 'cheesy', 'kids', 'seemed', 'like', 'moana', 'character', 'sorta', 'looked', 'like', 'moana', 'ladies', 'might', 'want', 'watch', 'movie', 'hula', 'correctly', 'funny', 'see', 'one', 'drummers', 'body', 'suit', 'make', 'look', 'tanned', 'maori', 'tattoosthe', 'parade', 'normal', 'characters', 'toy', 'story', 'lilo', '', 'stitch', 'etc', 'seemed', 'shorter', 'american', 'versionoverall', 'little', 'disney', 'entertaining', 'children', 'maybe', 'teenagers', 'spent', 'total', '3', 'hours']
# ['say', 'usa', 'disney', 'paris', 'one', 'worst', 'one', 'far', 'expensive', 'enter', 'expensive', 'buy', 'water', 'foodgifts', 'priced', 'toototally', 'disappointed', 'big', 'rides', 'everything', 'seemed', 'geared', 'towards', 'young', 'children', 'nothing', 'us', 'big', 'kidsdont', 'waste', 'money', 'save', 'go', 'usa', 'best', 'disney', 'far']
# ['definitely', 'must', 'visit', 'lifetime', 'definitely', 'look', 'forward', 'go', 'back', 'sad', 'castle', 'closed', 'renovation', 'fireworks', 'longer', 'part', 'lineup', 'thanks', 'staff', 'especially', 'ones', 'lilo', 'stitch', 'costumes', 'welcoming', 'fun', 'rides', 'also', 'fun', 'wasnt', 'absurd', 'amount', 'waiting', 'time', 'compared', 'theme', 'parks', 'similar', 'scalethank', 'disneyland', 'hong', 'kong']
# ['second', 'time', 'loved', 'place', 'atmosphere', 'bad', 'fantasyland', 'closed', 'renovation', 'staff', 'extremely', 'helpful', 'toilets', 'found', 'everywhere', 'clean', 'merch', 'expensive', 'though']
# ['hugely', 'expensive', '', '', '12640', 'one', 'adult', 'one', '14yo', 'surely', 'must', 'smallest', 'disneys', 'park', 'offerings', 'expect', 'western', 'style', 'junk', 'food', 'think', 'worse', 'rides', 'good', 'queue', 'discipline', 'times', 'bad', 'ignorant', 'people', 'shoving', 'kids', 'past', 'us', 'kids', 'cried', 'adults', 'couldnt', 'get', 'join', 'reluctantly', 'let', 'fairytale', 'castle', 'tiny', 'behind', 'hoardings', 'guess', 'working', 'add', 'extra', 'magic', 'diggers', 'go', 'ocean', 'park', 'instead']
# ['visited', 'walt', 'disney', 'world', 'disneyland', 'ca', 'small', 'one', '', 'however', 'plus', 'side', 'crowed', 'admission', 'expensive', 'walt', 'disney', 'world', 'disneyland', 'ca']
# ['priced', 'overly', 'busy', 'attractions', 'expensive', 'food', 'drinks', 'generally', 'worth', 'effort', 'attendance', 'compared', 'alternative', 'parks', 'hong', 'kong']
# ['went', 'sisters', 'things', 'expected', 'transportation', 'quite', 'convenient', 'busy', 'j', '', 'need', 'queue', 'long', 'sad', 'got', 'sick', 'ride', 'fine', 'end', 'waffle', 'cute', '', 'miss']
# ['small', 'dated', 'poor', 'facilities', 'young', 'children', 'enjoy', 'place', 'food', 'expensive']
# ['read', 'reviews', 'small', 'rated', 'went', 'found', 'better', 'expected', '', 'went', 'monday', 'height', 'august', 'summer', 'holidays', 'rained', 'slightly', 'morning', '', 'deter', 'themore']
# ['quite', 'expensive', 'much', 'see', 'rides', 'overcrouded', 'waiting', 'times', 'hour', 'first', 'time', 'might', 'okey', 'second', 'visit']
# ['disneyland', 'sea', 'definitely', 'one', 'worst', 'encountered', 'yes', 'staff', 'friendly', 'helpful', 'well', 'met', 'quite', 'handful', 'staff', 'typical', 'arrogant', 'attitude', 'faced', 'explorer', 'hotel', 'sure', 'staff', 'train', 'put', 'arrogant', 'attitude', 'case', 'good', 'job', 'disneyland', 'hongkong', 'pissed', 'turned', '1', 'many', 'touristwill', 'never', 'ever', 'visit', 'horrible', 'place']
# ['small', 'version', 'orlando', 'subtle', 'asian', 'influences', 'necessary', '', 'balanced', 'subtle', 'work', 'well', 'mostly', 'american', 'theme', 'park', 'experience']
# ['went', 'visit', 'hk', 'disneyland', '', 'small', 'park', 'compared', 'eurodisney', 'parked', 'packed', 'went', 'tuesday', 'disneyland', 'queue', '45mins', 'average', 'playing', '', '', 'pirates', 'caribean', '', '', 'peter', 'pan', '', 'attraction']
# ['smallest', 'disneyland', 'finish', 'walking', 'whole', 'place', '30min', 'strongly', 'recommend', 'even', 'spend', 'time', '', 'service', 'also', 'bad']
# ['made', 'mistake', 'coming', 'lunch', 'planning', 'see', '845pm', 'parade', 'want', 'overtire', 'son', 'come', 'earlier', 'time', 'see', 'exhibitbought', '4meal', 'coupon', '5', 'us', 'provided', 'much', 'food', 'portion', 'quite', 'generousyou', 'rent', 'stroller', 'fire', 'station', 'main', 'st', '120khd', 'recommended', 'youre', 'bringing', 'small', 'children']
# ['little', 'disappointing', 'disneyland', 'anaheim', 'florida', 'one', 'much', 'smaller', 'many', 'rides', 'water', 'rides', 'hot', 'disappointed', 'thatother', 'st', 'miniature', 'version', 'real', 'thing']
# ['raining', '', 'day', 'visited', 'rides', 'closed', 'open', 'short', 'immediately', 'waiting', '30', 'mins', 'rain', 'played', 'spoil', 'sport', 'many', 'options', 'older', 'boys', 'son', '', '9', 'yrs', 'quite', 'bored', 'couple', 'rides', 'also', 'due', 'technical', 'issues']
# ['like', 'queuing', 'behind', 'thousands', 'mainland', 'tourists', 'hours', 'visit', 'attractionit', 'small', 'way', 'airportthe', 'govt', 'allocated', 'equal', 'portion', 'land', 'expansion', 'adjoining', 'site', 'taken', 'onbetter', 'go', 'ocean', 'park']
# ['place', 'looks', 'old', 'outdated', '', 'food', 'expensive', '', 'hard', 'get', 'coffee', 'anywhere', '', '', 'layout', 'place', '', 'save', 'money', 'go', 'disneyland', 'tokyo', 'instead']
# ['got', 'surprised', 'see', 'small', 'disney', 'florida', 'though', 'one', 'hong', 'kong', 'would', 'least', 'fifth', 'size', 'nonetheless', 'virtually', 'lines', 'mainlymore']
# ['worth', 'money', 'yes', 'tickets', 'expensive', 'quality', 'rides', 'well', 'kept', 'grounds', 'worth', 'investment', 'five', 'year', 'old', 'complain', 'walking', '15500', 'steps', 'fitbit', 'usually', 'would', 'complain', 'walking', '200', 'stepsmore']
# ['hate', 'give', 'disney', 'bad', 'review', 'hong', 'kong', 'disneyland', 'four', 'years', 'bit', 'disappointed', 'today', 'quite', '', 'pointe', '', 'lacked', '', 'disney', 'magic', '', '', 'small', 'things', 'place', 'example', 'lights', 'working', 'rain', 'chains', 'lying', 'correctly', 'rain', 'forest', 'scene', '', '', 'small', 'world', '', '', 'maintenance', 'man', 'fixing', 'gate', 'even', 'used', 'tools', 'ground', 'front', 'line', '', 'ironman', 'experience', '', 'visitors', 'walking', 'ride', 'majority', 'non', 'performing', 'cast', 'members', 'looking', 'like', 'hated', 'jobs', '', 'smileswe', 'looking', 'forward', 'seeing', 'new', 'moana', 'show', 'venue', 'absolutely', 'ridiculous', 'three', 'rows', 'seats', 'area', 'could', 'accommodate', 'lot', 'much', 'shade', 'cover', 'unless', 'got', 'seats', 'stand', 'hot', 'sun', '20', 'minutes', 'watch', 'made', 'entire', 'show', 'unenjoyable', 'real', 'downer', 'kids', 'hated', 'said', 'worst', 'part', 'day', '', 'seriously', 'seemed', 'like', 'disney', 'took', 'cheap', 'route', 'create', 'new', 'entertainment', 'itemalso', 'see', 'posted', 'anywhere', 'even', 'disneyland', 'app', 'close', 'rides', 'back', 'park', 'one', 'hour', 'closing', 'time', '', 'wasted', 'time', 'walking', 'back', 'park', 'ride', 'rides', 'would', 'changed', 'evening', 'schedule', 'known', 'would', 'close', 'early', 'used', 'love', 'riding', 'mine', 'cars', 'dark', 'park', 'closedmy', 'sister', 'visiting', 'us', 'avid', 'disney', 'fan', 'said', '', 'wonder', 'one', 'comes', 'disneyland', 'park', 'open', 'enough', 'hours', 'get', 'money', '', 'worth', 'close', 'rides', 'early', 'lot', 'shade', 'cover', 'compared', 'hot', 'location', 'walt', 'disney', 'world', 'florida', '', 'expect', 'disney', 'thankfully', 'new', 'light', 'parade', 'fantastic', 'day', 'ended', 'classic', '', 'disney', 'magic', '', '']
# ['extremely', 'hot', 'weather', 'june', 'avoid', 'summer', 'timethe', 'place', 'small', 'manageable', 'family', 'young', 'childrengo', 'straight', 'fantasyland', 'kids', '6', 'go', 'ridesthe', 'night', 'parade', 'worth', 'watch', 'bit', 'disappointed', 'didnt', 'get', 'see', 'disney', 'characters', 'walking', 'photo', 'takingcastle', 'also', 'closed', 'fireworks', 'night']
# ['disney', 'fans', 'hate', 'standing', 'long', 'lines', 'like', 'us', 'try', 'hk', 'disneyland', 'weekdays', 'slow', 'shows', 'food', 'great']
# ['ive', 'several', 'times', 'since', 'first', 'opened', '', 'first', 'visit', 'disappointing', 'park', 'much', 'smaller', 'dlands', '', 'everything', 'go', 'park', 'seems', 'expanded', 'time']
# ['24', 'hours', 'enough', 'must', 'go', 'back', 'spend', 'least', '2', 'days', 'much', 'see', 'little', 'time', '']
# ['brings', 'back', 'childhood', 'memories', 'bit', 'crowded', 'expect', 'long', 'lines', 'everywhere', 'also', 'requires', 'lot', 'walking', 'patience']
# ['ignore', 'bad', 'reviews', 'went', 'today', 'amazing', 'time', 'yes', '', 'small', 'park', 'compared', 'disney', 'world', 'florida', 'expected', 'got', 'rides', 'walk', 'cast', 'members', 'friendly', 'know', 'come', 'summer', 'rains', 'lot', 'bring', 'umbrella']
# ['average', 'expectations', 'going', 'smallest', 'disney', 'parks', 'anaheim', 'however', 'greeted', 'disney', 'finest', 'smaller', 'park', 'size', 'somewhat', 'advantage', 'got', 'like', 'ride', 'rides', 'see', 'shows', 'disappoint', 'castle', 'bit', 'let', 'however', 'currently', 'construction', 'shortly', 'par', 'toy', 'story', 'area', 'definitely', 'must', 'see']
# ['visited', 'sunday', 'unfortunately', 'one', 'hot', 'bright', 'days', '3rd', 'june', 'meant', 'couldnt', 'cover', 'much', 'wasted', 'much', 'time', 'exhausted', 'start', 'waiting', 'customary', 'mickey', 'minnie', 'photo', 'skip', 'line', 'long', 'esp', 'staying', 'one', 'disney', 'hotels', 'anyway', 'meet', 'breakfast', 'plan', 'itinerary', 'well', 'fun', 'going', 'one', 'land', 'another', 'confusion', 'much', 'hot', 'food', 'overpriced', 'dont', 'accept', 'anything', 'cash', 'small', 'purchases', 'like', 'icecream', 'although', 'say', 'outside', 'food', 'drink', 'allowed', 'one', 'really', 'objected', 'although', 'checked', 'bags', 'rides', 'like', 'dumbo', 'small', 'world', 'really', 'worth', 'waiting', 'lines', 'winnie', 'pooh', 'boat', 'ride', 'long', 'ride', 'quite', 'repetitive', 'guess', 'prioritize', 'based', 'interests', 'cant', 'cover', 'time', 'made', 'lion', 'king', 'show', 'near', 'collapse', 'afraid', 'son', 'caught', 'heat', 'stroke', 'beat', 'hasty', 'retreat', 'happiest', 'place', 'earth', 'way', 'weather', 'careful', 'visit', 'may', 'june', 'small', 'kids']
# ['fanstastic', 'specially', 'people', 'come', 'holiday', 'kids', 'must', 'visit', 'disneyland', 'stay', 'park', 'area', 'cover', 'rides', 'shows', 'stay', '2', 'days', 'besides', 'rides', 'must', 'try', 'see', 'shows', 'currently', 'going', 'lion', 'king', 'show', 'fabulous', 'dont', 'miss', 'parades', 'afternoon', 'well', 'night', 'parade', 'different', 'unfortunately', 'visit', 'castle', 'closed', 'fireworks', 'try', 'cover', 'tomorrowland', 'adventure', 'land', '1st', 'maximumn', 'waiting', 'time']
# ['gold', 'coast', 'spoilt', 'amazing', 'theme', 'parks', 'tick', 'disneyland', 'hong', 'kong', 'place', 'well', 'done', 'hardly', 'rides', 'small', 'park', 'rides', 'geared', 'toddlers', 'disneys', 'target', 'marketif', 'teenagers', 'wouldnt', 'suggest', 'kids', 'disappointed']
# ['disneyland', 'la', 'thought', 'disneylands', 'identical', 'obviously', 'could', 'geographical', 'constraints', 'economic', 'restraints', 'havent', 'disneylands', 'around', 'world', 'hk', 'come', 'disneyland', 'la', 'disappointed']
# ['fireworks', 'castle', 'undergoing', 'transformation', '', '', 'since', 'already', 'small', 'version', 'transformation', 'areas', 'made', 'much', 'smaller', '', '']
# ['love', 'hong', 'kong', 'disneyland', 'try', 'avoid', 'month', 'may', 'july', 'heat', 'crazy', 'crowd', 'alright', 'weekdays', 'rides', 'took', '5', '10', 'minutes', 'queue', 'make', 'sure', 'bring', 'empty', 'bottles', 'water', 'refills', 'near', 'toilets', 'unless', 'would', 'like', 'pay', 'ripped', 'price', 'mineral', 'bottle', 'water', 'food', 'expensive', 'nice', 'cinderella', 'price', 'kinda', 'disappointing', 'avoid', 'renting', 'baby', 'strollers', 'summer', 'unless', 'want', 'bake', 'sun', 'burn', 'baby', 'main', 'castle', 'closed', 'renovationvery', 'disappointing', 'poor', 'dancers', 'sweating', 'much', 'custume', 'parade', 'generally', 'visit', 'mystic', 'manor', 'must', 'visit']
# ['tight', 'schedule', 'go', '1', 'day', '', 'made', '', 'highlight', 'iron', 'man']
# ['take', 'food', 'pack', 'food', 'properly', 'keep', 'bag', 'security', 'person', 'checks', 'bag', 'randomly', 'indians', 'cant', 'eat', 'local', 'food', 'get', 'take', 'enough', 'food', '']
# ['hyped', 'park', 'nothing', 'compared', 'disney', 'us', 'paris', '', 'ocean', 'park', '1000', 'times', 'better', '', 'rides', 'silly', 'uncovered', 'areas', 'difficult', 'summer', '', '', 'allow', 'outside', 'food', 'water', 'even', 'ready', 'pay', 'exorbitant', 'charges', 'lunch', 'provide', 'set', 'indian', 'lunch', 'tasteless', 'moreover', '', 'choice', '', 'wait', 'least', 'half', 'hour', 'queue', 'even', 'lunch', '', 'rides', 'closed', 'fire', 'works', 'day', 'went', '14th', 'may', '', 'considering', 'fireworks', 'must', 'see', '', 'announcement', 'anywhere', 'cancellation', '', 'strictly', 'avoid', 'summer', 'also', 'weekends', '', '', 'buy', 'two', 'day', 'pass', 'one', 'day', 'sufficient', '', 'visit', 'planning', 'visit', 'us', 'disney', 'otherwise', 'nothing', 'talk', 'one']
# ['taken', 'two', 'day', 'pass', 'didnt', 'come', 'second', 'day', 'easily', 'covered', 'day', 'ocean', 'park', 'definitely', 'exciting', 'disney', 'also', 'visited', 'universal', 'studios', 'may', 'disappointed', 'disney']
# ['', 'tokyo', 'disneyland', 'hk', 'fun', 'bit', 'disappointing', 'castle', 'closed', 'bring', 'umbrella', 'rain', 'hail', 'shine']
# ['disneyland', 'happiest', 'place', 'except', 'buying', 'souvenirs', 'stuffs', '', 'say', 'place', 'make', 'make', 'want', 'child', '', 'place', 'skip', 'visiting', '', 'hong', 'kong', '2nd', 'time', 'visit', 'still', '', 'get', 'enough', 'experience', 'singing', 'casts', 'dancing', 'dancing', 'swaying', 'feeling', 'disappointment', 'got', 'unexpected', 'selfie', 'pluto', 'camera', '10s', 'mode']
# ['im', 'bit', 'disappointed', 'disneyland', 'trip', 'year', 'castle', 'main', 'street', 'train', 'station', 'construction', 'closed', 'buzz', 'lightyear', 'astroblasters', 'ride', 'much', 'fun', 'despite', 'conking', 'often']
# ['disneyland', 'extremely', 'disappointing', 'us', 'daughter', '11', 'rides', 'suited', '8', 'children', 'much', 'happens', 'atmosphere', 'pretty', 'low', 'key', 'music', 'played', 'constantly', 'throughout', 'park', 'sends', 'little', 'insane']
# ['visiting', 'five', 'month', 'old', 'baby', 'toddler', 'went', 'rides', 'height', 'limits', 'used', 'priority', 'pass', 'skip', 'line', 'slinky', 'dog', 'ride', 'let', 'us', 'sit', 'ride', 'dad', 'toddler', 'get', 'cart', 'behind', 'front', 'wanted', 'sit', 'together', 'got', 'waited', 'next', 'turn', 'waited', 'first', 'round', 'end', 'told', 'gave', 'bone', 'tickets', 'round', 'wait', 'one', 'round', 'would', 'get', 'third', 'round', 'finally', 'turn', 'staff', 'proceed', 'say', 'five', 'month', 'old', 'sit', 'seat', 'lap', 'got', 'angry', 'waited', 'three', 'rounds', 'even', 'sat', 'ride', 'cart', 'one', 'staff', 'says', 'word', 'baby', 'lap', 'sit', 'next', 'family', 'enjoy', 'ride', 'tell', '', 'infant', 'lap', '', 'even', 'sit', 'nothing', 'say', 'ride', 'sits', 'plenty', 'babies', '', 'pointing', 'toddlers', 'pre', 'school', 'aged', 'children', 'saying', 'babies', '', 'mine', 'blind', 'child', '', 'small', 'size', 'comparison', 'asked', 'manager', 'waiting', 'staff', 'let', 'ride', 'kicked', 'ran', 'away', 'hideif', 'told', 'saw', 'line', 'said', 'something', 'everything', 'would', 'fine', 'waited', 'front', 'eyes', 'even', 'sat', 'cart', 'three', 'rides', 'later', 'refuse', 'let', 'board', 'ride', 'saying', 'lap', 'sitting', 'waste', 'time', 'use', 'priority', 'pass']
# ['', 'usa', 'disneyland', 'knew', 'would', 'much', 'smaller', 'extremely', 'long', '45', '', 'min', 'wait', '3', 'min', 'ride', 'impress', 'us', 'add', 'air', 'pollution', 'day', 'went', 'classed', '', 'extreme', '', '3', 'times', 'beijing', 'found', 'got', 'home', 'wondered', 'disneyland', '', 'close', 'days', 'like', '', 'buy', 'food', 'unless', '', 'expensive', 'poor', 'quality', 'fast', 'food', 'parade', 'highlight']
# ['visited', 'place', '10th', 'april', '2018', 'unfortunately', 'hong', 'kong', 'disneyland', 'decided', 'undergo', 'major', 'renovation', 'main', 'building', 'photo', 'op', 'area', 'cinderella', 'castle', 'time', '', 'postpone', 'visit', 'coz', '', 'already', 'bought', 'plane', 'tickets', '', 'booked', 'hotel', 'room', '3', 'months', 'beforehandeven', 'weekday', 'place', 'terribly', 'crowded', 'lines', 'taking', 'photo', 'mickey', '', 'minnie', 'mouse', 'ridiculously', 'long', 'spent', 'hour', 'causing', 'us', 'able', 'go', 'rides', 'end', 'daymy', 'advice', 'go', 'sometime', '2023', 'onwards', 'last', 'addition', 'new', 'marvel', 'themed', 'attraction', 'scheduled', 'open']
# ['never', 'get', 'tired', 'visiting', 'disneyland', '', 'looking', 'forward', 'outcome', 'ongoing', 'renovations']
# ['way', 'less', 'crowded', 'tokyo', 'much', 'smaller', 'fun', 'rides', 'teens', 'like', 'space', 'mountain', 'mine', 'ride', 'relatively', 'short', 'queues', 'iron', 'man', '4d', 'bad', 'pretty', 'fun', 'ride', 'toy', 'story', 'land', 'rest', 'rides', 'kids', 'like', 'mystic', 'manor', 'bad', 'either', 'tip', 'would', 'go', 'early', 'opens', 'around', '10am', 'larger', 'crowds', 'come']
# ['someone', 'avid', 'disney', 'fan', 'park', 'disappointing', '', 'western', 'shows', 'oriental', 'culture', '', 'even', 'celebrate', 'mulan', 'castle', 'mainstreet', 'miniature', 'laughable', 'compared', 'paris', 'florida', 'two', 'small', 'rollercoasters', 'fast', 'speed', 'thrill', 'chasers', 'parades', 'lots', 'things', 'closed', 'refurbishment', 'lacked', 'disney', 'magic', 'feel', 'parks']
# ['went', 'late', 'last', 'year', 'little', 'disappointed', 'realising', 'park', 'really', 'caters', 'young', 'kids', 'family', '16', 'years', 'ages', 'found', 'got', 'really', 'bored', 'instead', 'fun']
# ['big', 'expected', 'definitely', 'consumed', 'entire', 'day', 'youll', 'definitely', 'feel', 'young', 'moment', 'step', 'foot', 'place', 'place', 'channel', 'inner', 'child', '', 'every', 'rides', 'attractions', 'stop', 'parade', 'resume', 'operations', 'miss', 'fireworks', 'show', 'tooexpect', 'food', 'even', 'smallest', 'item', 'gift', 'shops', 'pricey', 'cannot', 'bring', 'outside', 'food', 'snacks', 'inside', 'park', 'cheapest', 'bottled', 'water', 'could', 'buy', 'park', 'located', 'entrance', 'besides', 'gift', 'shop']
# ['youll', 'feel', 'like', 'kid', 'abit', 'expensive', 'worth', 'trip', 'would', 'suggest', 'eat', 'fairytale', 'banquet', 'hall', 'near', 'dumbo', 'buy', 'klook', 'food', 'coupon', 'online', 'hell', 'lot', 'cheaper']
# ['went', 'cny', 'period', '20', 'feb', '2018', 'corwded', 'tourist', 'fine', 'understandable', 'alot', 'rude', 'tourist', 'like', 'cut', 'queue', 'hope', 'disneyland', 'management', 'pay', 'attention', 'disallow', 'rude', 'uncivilize', 'action']
# ['disneyland', 'disappoint', 'plenty', 'activities', 'attractions', 'rides', 'however', 'one', 'advantage', 'compared', 'orlando', 'compact', 'still', 'crowded', 'dont', 'take', 'long', 'walk', 'one', 'side']
# ...
# ['live', 'hk', 'take', '3', 'year', 'old', 'son', 'disneyland', 'often', 'continually', 'frustrated', 'number', 'rude', 'adults', 'attend', 'show', 'consideration', 'small', 'children', 'lines', '', 'even', 'see', 'kids', 'parade', 'b', 'c', 'want', 'standing', 'right', 'front', 'yesterday', 'monday', 'waited', 'ages', 'get', 'car', 'ride', '80', 'people', 'adults', 'think', 'need', 'express', 'lane', 'kidsthey', 'usually', 'need', 'go', 'toilet', '1', 'hour', 'oh', 'sorry', 'must', 'line', 'uuurrgghhand', '30', 'year', 'old', 'women', 'acting', 'like', 'minnie', 'mouse', 'anyway', 'surere', 'live', 'childhood', 'kind', 'small', 'child', 'also', '', 'itching', '', 'see', 'winnie', 'pooh']
# ['3rd', 'trip', 'hk', 'disneyland', '2005', '6', 'long', 'open', 'park', 'awful', 'seems', 'improve', 'slowly', 'timewe', 'family', 'disney', 'affectionados', 'disney', 'world', 'disneyland', 'anaheim', 'tokyo', 'disneyland', 'fifty', 'times', 'combined', 'feel', 'hk', 'disneyland', 'really', 'small', 'called', 'disneyland', 'way', 'rides', 'attractions', 'came', 'hk', 'disneyland', 'see', 'new', 'small', 'world', 'attraction', 'perhaps', 'best', 'small', 'world', 'disney', 'parks', 'numerous', 'disney', 'characters', 'like', 'mulan', 'simba', 'peter', 'pan', 'aladdin', 'style', 'dolls', 'entire', 'area', 'right', 'next', 'golden', 'mickeys', 'also', 'well', 'done', 'however', 'disappointed', 'stich', 'encounter', 'attraction', 'attraction', 'small', 'wait', 'long', '45', 'minutes', 'worth', 'actually', 'thought', 'show', 'area', 'pre', 'show', 'area', 'tiny', 'poorly', 'done', 'obvious', 'attraction', 'hashed', 'together', 'last', 'minute', 'address', 'shortfall', 'attractions', 'parki', 'seriously', 'hope', 'hk', 'disneyland', 'could', 'include', 'signature', 'disney', 'attractions', 'available', 'parks', 'namely', 'haunted', 'mansion', 'splash', 'mountain', 'big', 'thunder', 'mountain', 'toontown', 'every', 'year', 'park', 'failed', 'meet', 'attendance', 'expectation', 'says', 'lot', 'quality', 'parkbasically', 'park', 'good', 'small', 'children', 'people', 'never', 'disney', 'grow', 'real', 'disney', 'park', 'hk', 'disneyland']
# ['disneyland', 'quite', 'small', 'compared', 'others', 'suited', 'small', 'kids', '11', 'years', 'old', 'rides', 'shows', 'nearly', 'everything', 'else', 'meant', 'themwell', 'know', 'disneyland', 'meant', 'small', 'kids', 'bigger', 'parks', 'cater', 'adults', 'teenagers', 'adults', 'park', 'waste', 'money', '2', 'rides', 'worthwhile']
# ['23', 'dec', '2007', '', 'experience', 'fantasies', 'ever', 'imagined', 'disneyland', 'disneyland', 'hong', 'kong', 'consist', '', 'adventure', 'land', 'fantasy', 'land', 'tomorrow', 'land', 'however', 'spent', 'time', 'fantasy', 'land', 'arrived', '11', 'departedmore']
# ['numerous', 'times', 'disney', 'parks', 'paris', 'orlando', 'anaheim', '', 'hesitate', 'add', 'hong', 'kong', 'list', 'go', 'knowing', 'advance', 'much', 'smaller', 'park', '', 'disappointed', 'found', 'amore']
# ['entrance', 'fee', 'bit', 'steep', 'one', 'time', 'entry', '', 'like', 'small', 'theme', 'park', 'rather', 'disneyland', '', 'expected', 'actually']
# ['recently', 'travelled', 'disneyland', '9', 'year', 'old', 'daughterit', 'long', 'day', 'arrived', 'early', 'park', 'opened', 'end', 'fireworksthe', 'rides', 'disney', 'surpassed', 'rides', 'ocean', 'park', 'level', 'comfort', 'experience', 'disney', 'amazing', 'air', 'con', 'fans', 'throughout', 'park', 'meant', 'whenever', 'got', 'little', 'bit', 'hot', 'able', 'take', '5', 'minutes', 'air', 'conditioned', 'shop', 'cool', 'offprobably', 'frustrating', 'thing', 'encountered', 'children', 'pushing', 'cutting', 'lines', 'lining', 'see', 'front', 'line', 'last', 'thing', 'want', 'see', 'children', 'streaming', 'past', 'relative', 'front', 'linethis', 'happened', 'lot', '', 'especially', 'lining', 'photos', 'taken', 'disney', 'characters', 'take', 'much', 'suits', 'need', '5', 'minute', 'break', 'nothing', 'frustrating', '10', 'kids', 'cut', 'front', 'line', 'photos', 'taken', 'told', 'mickey', 'take', '5overall', '', 'disney', 'experince', 'think', 'said', 'disney', 'parks', 'throughout', 'world', 'would', 'probably', 'disappointed', 'hk', 'parki', 'also', 'write', 'review', 'ocean', 'park', 'another', 'must', 'families', 'children']
# ['went', 'last', 'year', 'son', 'aged', '11', 'enjoyed', 'without', 'reservation', 'however', 'disney', 'anaheim', 'wife', 'anaheim', 'florida', 'france', 'found', 'little', 'bit', 'small', 'tame', 'kids', 'little', 'older', 'keen', 'really', 'wild', 'rides', 'theyre', 'going', 'disappointed', 'hand', 'smaller', 'children', 'probably', 'really', 'enjoy', 'apart', 'size', 'standard', 'disney', 'experience', 'ocean', 'park', 'may', 'better', 'bet']
# ['disneyland', 'hong', 'kong', 'twice', 'thus', 'far', 'first', 'time', 'october', '2005', 'returned', 'second', 'trip', 'stayed', 'disneyland', 'hotel', '2005', '2006', 'well', 'park', 'disappointment', 'crowds', 'heavy', 'lack', 'rides', 'disappointing', 'addition', 'enough', 'things', 'see', 'small', 'finished', 'rides', 'shows', '1', '2', 'day', 'kids', 'bored', 'didnt', 'even', 'want', 'go', 'rides', 'wow', 'different', 'florida', 'california', 'usa', 'want', 'shop', 'eat', 'terrible', 'food', 'come', 'hk', 'disney', 'save', 'money', 'go', 'real', 'thing', 'usa', 'also', 'disneyland', 'hotel', 'accomodations', 'nice', 'however', 'kid', 'friendly', 'theme', 'park', 'hotels', 'hotel', 'halloween', 'games', 'activities', 'flop', 'ended', '2', 'young', 'men', 'staff', 'disneyland', 'hotel', 'put', 'games', 'tables', 'stood', 'door', 'watching', 'kids', 'play', 'addition', 'activities', 'time', 'kids', 'given', 'coloring', 'books', 'crayons', 'table', 'told', 'color', 'away', 'disney', 'characterseven', 'storytime', 'pitiful', 'young', 'male', 'staff', 'member', 'merely', 'summarized', 'page', '1', 'pooh', 'book', 'sent', 'children', 'away', 'afterwards', 'really', 'need', 'work', 'quality', 'food', 'theme', 'park', 'hotel', 'well', 'bad', 'save', 'money', 'go', 'somewhere', 'else']
# ['read', 'much', 'bad', 'publicity', 'expecting', 'bad', 'disneyland', 'wasnt', 'disappointed', 'pleasantly', 'surprised', 'either', 'went', 'morning', 'everyone', 'said', 'queue', 'least', '1', '2', 'hours', 'long', 'fastpass', 'isnt', 'useful', 'either', 'first', 'fastpass', 'could', 'go', 'back', 'within', '1', 'hour', 'second', 'fastpass', 'obtained', '1pm', 'allowed', 'take', 'ride', '630', 'rides', 'mostly', 'boring', 'theres', '1', 'rollercoaster', 'ish', 'ride', 'space', 'mountain', 'quite', 'good', 'isnt', 'really', 'exciting', 'ive', 'tried', 'better', 'less', 'known', 'themeparks', 'objectively', 'enjoyeable', 'reallyif', 'kids', 'like', 'disney', 'characters', 'might', 'nice', 'see', 'walking', 'around', 'buy', 'disney', 'merchandise', 'im', 'really', 'fan', 'big', 'deal', 'methe', 'queue', 'cutting', 'wasnt', 'bad', 'people', 'shamelessly', 'walking', 'past', 'us', 'get', 'friends', 'booked', 'place', 'queue', 'front', 'put', 'feet', 'tell', 'person', 'shamelessly', 'saying', '', 'excuse', '', 'blocked', 'way', 'trying', 'go', 'front', 'queue', 'really', 'common', 'people', 'make', 'sound', 'probably', 'people', 'everywhere', 'reason', 'point', 'fingers', 'mainlanders', 'say', 'social', 'etiquettesome', 'things', 'well', 'done', 'include', '3d', 'animation', 'mickey', 'show', 'forgot', 'name', 'shall', 'reveal', 'reason', 'good', 'surprise', 'element', 'part', 'fun', 'fireworks', 'performance', 'night', 'also', 'really', 'amazinga', 'recommendation', '', 'go', 'evening', 'queues', 'eased', 'youll', 'probably', 'complete', 'number', 'rides', 'less', 'frustration', 'start', 'day', 'spend', 'time', 'queue', 'wont', 'miss', 'fireworks']
# ['hong', 'kong', '5', 'weeks', 'disney', 'fans', 'disney', 'parks', 'usa', 'paris', 'many', 'times', 'little', 'research', 'expected', 'park', 'small', 'crowded', 'holidays', 'rude', 'queue', 'jumping', 'mainlanders', 'weather', 'hot', 'expectations', 'fulfilledhowever', 'expect', 'encounter', 'rude', 'cmswe', 'entered', 'adventureland', 'main', 'street', 'stall', 'right', 'entrance', 'wanted', 'fast', 'passes', 'lion', 'king', 'show', 'asked', 'girl', 'store', 'directions', 'pointed', 'us', 'girl', 'busy', 'one', 'else', 'holding', 'little', 'fan', 'face', 'dont', 'blame', 'heat', 'apparently', 'allowed', 'anyway', 'children', 'pin', 'trade', 'lanyard', 'around', 'glanced', 'pins', 'lanyard', 'immediately', 'held', 'lanyard', 'said', 'friendly', 'voice', '', 'want', 'see', 'dont', 'ask', 'feel', 'embarassed', 'look', 'like', '', 'imagine', 'shock', 'im', 'woman', '42', 'two', 'kids', 'tow', '', 'would', 'think', 'staring', 'anything', 'lanyard', 'shocked', 'said', 'attitude', 'didnt', 'know', 'react', 'turned', 'around', 'walked', 'away', 'really', 'said', 'something', 'heranyway', 'thought', 'uncomfortable', 'felt', 'really', 'accusing', 'something', 'nasty', 'went', 'city', 'hall', 'told', 'cm', 'experience', 'nasty', 'cms', 'name', 'mandy', 'cm', 'city', 'hall', 'sympathetic', 'write', 'report', 'said', 'mandy', 'must', 'bad', 'day', 'said', 'excuse', 'speak', 'guest', 'way', 'said', 'hoped', 'experience', 'spoil', 'day', 'said', 'course', 'otherwise', 'would', 'standing', 'front', 'heri', 'told', 'met', 'cms', 'florida', 'last', 'summer', 'sent', 'training', 'know', 'lucky', 'ones', 'cannot', 'send', 'everyone', 'trained', 'maybe', 'expecting', 'cms', 'like', 'ones', 'disney', 'parks', 'hong', 'kong', 'disneyland', 'train', 'cms', 'better', 'service', 'attitude', 'also', 'afraid', 'speak', 'mainlanders', 'clearly', 'queue', 'jumping', 'acting', 'non', 'sociable', 'manner', 'saw', 'incident', 'cm', 'let', 'mainlander', 'queue', 'jumpwe', 'stayed', 'disneyland', 'hotel', 'last', 'two', 'nights', 'trip', 'hotel', 'beautiful', 'beds', 'comfortable', 'pool', 'last', 'day', 'lifeguards', 'pool', 'looked', 'bored', 'slide', 'lifeguard', 'top', 'slide', 'red', 'light', 'green', 'light', 'obviously', 'light', 'green', 'slide', 'water', 'slide', 'although', 'lifeguard', 'watched', 'looking', 'whether', 'going', 'light', 'green', 'red', 'fact', 'looking', 'us', 'young', 'children', 'queue', 'little', 'shocked', 'thisi', 'visit', 'hk', 'disneyland', 'near', 'future', 'return', 'attractions', 'hope', 'mainlanders', 'learnt', 'social', 'skills', '', 'catch', 'quickly', 'see', 'spitting', 'cms', '', 'maybe', 'disney', 'give', 'training', 'pay']
# ['hk', 'disney', 'boring', '', 'go', 'ocean', 'park', '', 'go', 'la', 'disney', '', 'dont', 'go', 'hk', 'disney']
# ['waste', 'time', 'money', 'think', 'planning', 'bringing', 'teenage', 'kids', 'went', 'mate', 'mine', 'happened', 'time', '8', 'years', 'old', 'nothing', 'one', 'roller', 'coaster', 'space', 'mountain', 'described', 'lamemy', 'kids', 'favourite', 'word', 'banked', 'turns', 'g', 'forces', 'friends', 'nothing', 'else', 'rides', 'suit', 'anyone', '8', 'dumbo', 'ride', 'next', 'thrilling', 'ride', 'caters', 'anyone', 'age', '2', 'food', 'terrible', 'didnt', 'eat', 'end', 'live', 'asia', 'isnt', 'like', 'dont', 'eat', 'asian', 'food', 'park', 'small', 'rides', 'hopeless', 'food', 'awful', 'didnt', 'hang', 'around', 'fire', 'works', 'would', 'wait', 'another', 'five', 'hours', 'sick', 'thenif', 'decide', 'go', 'morning', 'afternoon', 'enough', 'pleased', 'didnt', 'bring', '2', 'teenage', 'boys', 'singapore', 'hk', 'waste', '2k', 'planes', 'hotels', 'would', 'happyone', 'positive', 'note', 'park', 'nearly', 'empty', 'short', 'queues', 'surprise', 'hindsight']
# ['spent', 'christmas', 'eva', 'park', '1130am', '830pm', '', 'day', 'bus', 'trip', 'guangzhou', '', 'going', 'china', 'hongkong', 'customs', 'worst', 'part', 'day', '', 'none', 'park', 'problems', 'reviewers', 'complained', '', 'bathrooms', 'trash', 'cans', 'water', 'fountains', 'allmore']
# ['husband', 'took', '2', 'kids', 'worst', 'experience', 'lives', 'mothers', 'take', 'heed', 'endangering', 'lives', 'children', 'bring', 'modern', 'day', 'sodom', 'gomorrahfirst', 'park', 'poorly', 'designed', 'incredibly', 'miniscule', 'hardly', 'rides', 'imagine', 'rides', 'course', 'lines', 'ridiculously', 'long', 'expect', 'wait', '3', 'hours', 'even', 'worst', 'rides', 'though', '', 'great', '', 'ones', 'even', 'come', 'mind', 'truly', 'believe', 'built', 'whole', 'park', 'around', 'fact', 'space', 'mountain', 'felt', 'like', 'enough', 'cheat', '', 'ignorant', '', 'clientele', 'believing', 'real', 'thing', 'real', 'disneyland', 'type', 'grew', 'best', 'ultra', 'mini', 'version', 'anything', 'made', 'ticket', 'prices', 'ultra', 'mini', 'well', 'way', 'hell', 'experience', 'worth', 'ticket', 'pricebut', 'speaking', 'clientele', 'may', 'worst', 'thing', 'hong', 'kong', 'disneyland', 'think', 'squeamish', 'type', 'parents', 'peace', 'corps', 'family', 'traveled', 'africa', 'south', 'america', 'grew', 'seeing', 'decay', 'disease', 'say', 'never', 'seen', 'greater', 'cesspool', 'human', 'waste', 'potential', 'spread', 'disease', 'hong', 'kong', 'disneylandmy', 'husband', 'gagged', 'nearly', 'threw', 'went', 'drink', 'water', 'find', 'feces', 'drinking', 'fountainwe', 'saw', 'mother', 'help', 'little', 'boy', 'trousers', 'urinated', 'next', 'food', 'standsmokers', 'everywhere', 'mind', 'disneyland', 'city', 'streets', 'smoking', 'public', 'repulsive', 'enough', 'husband', 'nearly', 'lost', 'man', 'blew', 'cigarette', 'smoke', 'faces', 'childrenmind', 'alerted', 'disney', 'staff', 'infractions', 'nothing', 'unbelievable', 'like', 'either', 'poorly', 'trained', 'instructed', 'turn', 'cheekwe', 'found', 'irreprehensible', 'park', 'officials', 'could', 'let', 'people', 'smoke', 'public', 'around', 'children', 'blow', 'smoke', 'childrens', 'faces', 'less', 'still', 'consider', '', 'kid', 'friendly', '', 'beyond', 'us', 'worst', 'disneyland', 'yes', 'smoking', 'everywhere', 'permitted', 'hong', 'kong', 'disneylandthere', 'hundreds', 'unsanitary', 'unsightly', 'things', 'encountered', 'visit', 'almost', 'many', 'mention', 'weve', 'never', 'seen', 'outwardly', 'anti', 'social', 'public', 'displays', 'ever', 'entire', 'lives', 'wiping', 'exposed', 'underarms', 'bare', 'hands', 'smelling', 'hand', 'putting', 'bare', 'feet', 'everywhere', 'park', 'benches', 'rubbing', 'picking', 'toenails', 'disgusting', 'times', 'would', 'think', 'toiling', 'away', 'chicken', 'farm', 'instead', 'spending', 'holiday', 'disneyland', 'shocking', 'thing', 'new', 'outbreaks', 'bird', 'flu', 'virus', 'predicated', 'happen', 'day', 'possibly', 'emergence', 'deadly', 'untreatable', 'version', 'sars', 'could', 'horrid', 'public', 'sanitation', 'behavior', 'places', 'disneylandwhen', 'consider', 'sars', 'originated', 'part', 'world', 'precisely', 'type', 'unsanitary', 'behavior', 'among', '30000', 'people', 'packed', 'space', 'third', 'size', 'disneyland', 'us', 'people', 'urinating', 'street', 'defecating', 'water', 'fountains', 'fact', 'highly', 'susceptible', 'type', 'diseases', 'whether', 'sars', 'h5n1', 'bird', 'fluwhats', 'hong', 'kong', 'disneyland', 'like', 'hot', 'box', 'second', 'hand', 'cigarette', 'smoke', 'children', 'either', 'exposing', 'dangers', 'highly', 'contagious', 'fatal', 'diseases', 'brought', 'unsanitary', 'conditions', 'human', 'behavior', 'preventable', 'diseases', 'cancer', 'inhaling', 'second', 'hand', 'smoke', 'visit', 'hong', 'kong', 'disneylandbesides', 'factors', 'place', 'supposed', 'fun', 'yes', 'unfortunately', 'place', 'close', 'family', 'holiday', 'get', 'burning', 'gates', 'hell', 'visit', 'hong', 'kong', 'disneyland']

# %%
from collections import Counter
word_counts = Counter()
N_HK['Review_Text'].apply(lambda x: word_counts.update(x))
count = word_counts.most_common()
count
# Out:
# [('', 876),
#  ('disneyland', 537),
#  ('disney', 471),
#  ('park', 457),
#  ('rides', 439),
#  ('day', 292),
#  ('small', 273),
#  ('time', 259),
#  ('food', 258),
#  ('one', 226),
#  ('go', 224),
#  ('kids', 220),
#  ('hong', 204),
#  ('kong', 200),
#  ('expensive', 176),
#  ('place', 172),
#  ('visit', 171),
#  ('would', 166),
#  ('like', 158),
#  ('hk', 158),
#  ('went', 155),
#  ('ride', 143),
#  ('parade', 140),
#  ('get', 137),
#  ('queue', 132),
#  ('dont', 130),
#  ('long', 130),
#  ('people', 122),
#  ('experience', 122),
#  ('even', 121),
#  ('bad', 121),
#  ('us', 118),
#  ('disappointed', 117),
#  ('see', 115),
#  ('staff', 115),
#  ('around', 111),
#  ('really', 108),
#  ('much', 104),
#  ('world', 103),
#  ('children', 101),
#  ('2', 100),
#  ('also', 99),
#  ('visited', 98),
#  ('little', 97),
#  ('queues', 95),
#  ('parks', 94),
#  ('fireworks', 90),
#  ('attractions', 88),
#  ('line', 87),
#  ('still', 85),
#  ('well', 84),
#  ('quite', 83),
#  ('wait', 81),
#  ('show', 81),
#  ('minutes', 78),
#  ('compared', 78),
#  ('crowded', 77),
#  ('take', 76),
#  ('waiting', 75),
#  ('characters', 74),
#  ('lot', 74),
#  ('two', 74),
#  ('theme', 73),
#  ('closed', 72),
#  ('first', 68),
#  ('good', 65),
#  ('never', 65),
#  ('however', 65),
#  ('shows', 65),
#  ('money', 65),
#  ('year', 65),
#  ('chinese', 65),
#  ('could', 64),
#  ('family', 64),
#  ('1', 63),
#  ('bit', 63),
#  ('train', 62),
#  ('fun', 62),
#  ('enough', 62),
#  ('3', 62),
#  ('must', 62),
#  ('going', 62),
#  ('old', 62),
#  ('less', 61),
#  ('back', 61),
#  ('lines', 60),
#  ('want', 60),
#  ('years', 60),
#  ('didnt', 60),
#  ('worth', 59),
#  ('land', 59),
#  ('trip', 59),
#  ('need', 58),
#  ('space', 58),
#  ('big', 57),
#  ('rude', 56),
#  ('say', 56),
#  ('think', 56),
#  ('smaller', 56),
#  ('days', 55),
#  ('mountain', 55),
#  ('tickets', 54),
#  ('visitors', 53),
#  ('hour', 53),
#  ('hours', 53),
#  ('adults', 52),
#  ('least', 52),
#  ('ticket', 52),
#  ('paris', 52),
#  ('recommend', 51),
#  ('disappointing', 51),
#  ('way', 50),
#  ('find', 50),
#  ('got', 50),
#  ('took', 50),
#  ('mickey', 50),
#  ('castle', 49),
#  ('every', 49),
#  ('times', 48),
#  ('5', 48),
#  ('tokyo', 47),
#  ('things', 46),
#  ('due', 45),
#  ('attraction', 45),
#  ('ocean', 44),
#  ('better', 44),
#  ('thing', 44),
#  ('water', 43),
#  ('bring', 43),
#  ('buy', 43),
#  ('weather', 43),
#  ('mainland', 43),
#  ('young', 43),
#  ('worst', 42),
#  ('half', 42),
#  ('found', 42),
#  ('waste', 41),
#  ('many', 41),
#  ('hot', 41),
#  ('everything', 41),
#  ('boring', 41),
#  ('entrance', 40),
#  ('price', 40),
#  ('said', 40),
#  ('made', 40),
#  ('nothing', 40),
#  ('definitely', 40),
#  ('visiting', 39),
#  ('lion', 39),
#  ('king', 39),
#  ('hotel', 39),
#  ('main', 39),
#  ('child', 39),
#  ('disappointment', 39),
#  ('since', 39),
#  ('last', 39),
#  ('come', 38),
#  ('4', 38),
#  ('new', 37),
#  ('tourists', 37),
#  ('inside', 37),
#  ('let', 36),
#  ('end', 36),
#  ('night', 36),
#  ('crowd', 36),
#  ('30', 35),
#  ('stay', 35),
#  ('though', 35),
#  ('avoid', 35),
#  ('florida', 34),
#  ('average', 34),
#  ('daughter', 34),
#  ('pass', 34),
#  ('great', 34),
#  ('another', 34),
#  ('feel', 33),
#  ('photos', 33),
#  ('area', 33),
#  ('size', 33),
#  ('know', 33),
#  ('whole', 33),
#  ('walk', 32),
#  ('10', 32),
#  ('maybe', 32),
#  ('try', 32),
#  ('lots', 32),
#  ('without', 32),
#  ('saw', 32),
#  ('spend', 32),
#  ('expect', 32),
#  ('may', 32),
#  ('rain', 31),
#  ('done', 31),
#  ('enjoy', 31),
#  ('enjoyed', 31),
#  ('expected', 31),
#  ('watch', 31),
#  ('crowds', 31),
#  ('short', 30),
#  ('wanted', 30),
#  ('bought', 30),
#  ('poor', 30),
#  ('orlando', 30),
#  ('rather', 30),
#  ('wasnt', 30),
#  ('service', 30),
#  ('china', 29),
#  ('ever', 29),
#  ('etc', 29),
#  ('hongkong', 29),
#  ('photo', 29),
#  ('english', 29),
#  ('ones', 29),
#  ('front', 29),
#  ('fast', 28),
#  ('far', 28),
#  ('terrible', 28),
#  ('parades', 28),
#  ('u', 28),
#  ('told', 28),
#  ('extremely', 28),
#  ('especially', 28),
#  ('cant', 28),
#  ('anaheim', 27),
#  ('shops', 27),
#  ('queuing', 27),
#  ('ive', 27),
#  ('thought', 27),
#  ('left', 27),
#  ('early', 27),
#  ('unfortunately', 27),
#  ('always', 27),
#  ('quality', 27),
#  ('7', 27),
#  ('miss', 27),
#  ('full', 27),
#  ('walking', 27),
#  ('pretty', 26),
#  ('limited', 26),
#  ('part', 26),
#  ('45', 26),
#  ('almost', 26),
#  ('felt', 26),
#  ('pushing', 25),
#  ('something', 25),
#  ('everyone', 25),
#  ('eat', 25),
#  ('toy', 25),
#  ('second', 25),
#  ('yes', 25),
#  ('although', 25),
#  ('15', 25),
#  ('usa', 25),
#  ('spent', 25),
#  ('smallest', 25),
#  ('hardly', 25),
#  ('plenty', 25),
#  ('others', 25),
#  ('evening', 24),
#  ('looking', 24),
#  ('probably', 24),
#  ('getting', 24),
#  ('rest', 23),
#  ('kid', 23),
#  ('weekday', 23),
#  ('arrived', 23),
#  ('afternoon', 23),
#  ('6', 23),
#  ('couple', 23),
#  ('came', 23),
#  ('give', 23),
#  ('taking', 23),
#  ('disneylands', 23),
#  ('la', 23),
#  ('side', 23),
#  ('cut', 23),
#  ('open', 22),
#  ('story', 22),
#  ('either', 22),
#  ('return', 22),
#  ('lunch', 22),
#  ('mins', 22),
#  ('wont', 22),
#  ('given', 22),
#  ('save', 22),
#  ('street', 22),
#  ('everywhere', 22),
#  ('understand', 22),
#  ('hkd', 22),
#  ('cutting', 21),
#  ('past', 21),
#  ('look', 21),
#  ('holidays', 21),
#  ('love', 21),
#  ('man', 21),
#  ('im', 21),
#  ('horrible', 21),
#  ('christmas', 21),
#  ('mouse', 21),
#  ('late', 21),
#  ('happiest', 21),
#  ('meet', 21),
#  ('make', 21),
#  ('character', 21),
#  ('adult', 21),
#  ('real', 21),
#  ('different', 21),
#  ('sure', 20),
#  ('might', 20),
#  ('pay', 20),
#  ('pm', 20),
#  ('nice', 20),
#  ('tired', 20),
#  ('several', 20),
#  ('compare', 20),
#  ('bored', 20),
#  ('start', 20),
#  ('packed', 20),
#  ('chicken', 20),
#  ('expecting', 20),
#  ('home', 19),
#  ('actually', 19),
#  ('restaurant', 19),
#  ('restaurants', 19),
#  ('20', 19),
#  ('already', 19),
#  ('suggest', 19),
#  ('mtr', 19),
#  ('asked', 19),
#  ('grizzly', 19),
#  ('halloween', 19),
#  ('close', 19),
#  ('outside', 19),
#  ('son', 19),
#  ('entry', 19),
#  ('anything', 19),
#  ('name', 19),
#  ('mainlanders', 19),
#  ('number', 19),
#  ('souvenirs', 18),
#  ('places', 18),
#  ('seems', 18),
#  ('decided', 18),
#  ('check', 18),
#  ('usual', 18),
#  ('california', 18),
#  ('theres', 18),
#  ('wouldnt', 18),
#  ('overall', 18),
#  ('earth', 18),
#  ('instead', 18),
#  ('mystic', 18),
#  ('wrong', 18),
#  ('minnie', 18),
#  ('raining', 18),
#  ('security', 18),
#  ('managed', 17),
#  ('seen', 17),
#  ('crazy', 17),
#  ('allowed', 17),
#  ('high', 17),
#  ('busy', 17),
#  ('japan', 17),
#  ('fact', 17),
#  ('else', 17),
#  ('lack', 17),
#  ('next', 17),
#  ('shop', 17),
#  ('tried', 17),
#  ('areas', 17),
#  ('universal', 17),
#  ('drinks', 17),
#  ('wife', 17),
#  ('magical', 17),
#  ('heat', 17),
#  ('magic', 17),
#  ('summer', 17),
#  ('baby', 17),
#  ('totally', 17),
#  ('younger', 17),
#  ('city', 17),
#  ('online', 16),
#  ('week', 16),
#  ('prices', 16),
#  ('parents', 16),
#  ('friendly', 16),
#  ('ago', 16),
#  ('couldnt', 16),
#  ('thats', 16),
#  ('9', 16),
#  ('public', 16),
#  ('star', 16),
#  ('best', 16),
#  ('cover', 16),
#  ('clean', 16),
#  ('seemed', 16),
#  ('total', 16),
#  ('sad', 16),
#  ('version', 16),
#  ('werent', 16),
#  ('mind', 16),
#  ('drink', 15),
#  ('point', 15),
#  ('unless', 15),
#  ('maintenance', 15),
#  ('light', 15),
#  ('iron', 15),
#  ('keep', 15),
#  ('plan', 15),
#  ('waited', 15),
#  ('jungle', 15),
#  ('entire', 15),
#  ('overpriced', 15),
#  ('three', 15),
#  ('management', 15),
#  ('twice', 15),
#  ('games', 15),
#  ('right', 15),
#  ('coaster', 15),
#  ('roller', 15),
#  ('trying', 14),
#  ('person', 14),
#  ('meal', 14),
#  ('stayed', 14),
#  ('merchandise', 14),
#  ('ridiculous', 14),
#  ('comparison', 14),
#  ('40', 14),
#  ('asian', 14),
#  ('worse', 14),
#  ('morning', 14),
#  ('please', 14),
#  ('booked', 14),
#  ('taste', 14),
#  ('youll', 14),
#  ('monday', 14),
#  ('holiday', 14),
#  ('ended', 14),
#  ('disneys', 14),
#  ('taken', 14),
#  ('looks', 14),
#  ('mine', 14),
#  ('skip', 14),
#  ('exciting', 14),
#  ('except', 14),
#  ('away', 14),
#  ('anyone', 14),
#  ('fee', 14),
#  ('favourite', 14),
#  ('called', 13),
#  ('weekends', 13),
#  ('doesnt', 13),
#  ('longest', 13),
#  ('buzz', 13),
#  ('awful', 13),
#  ('youve', 13),
#  ('3d', 13),
#  ('youre', 13),
#  ('used', 13),
#  ('picture', 13),
#  ('stand', 13),
#  ('adventure', 13),
#  ('cruise', 13),
#  ('earlier', 13),
#  ('within', 13),
#  ('12', 13),
#  ('cold', 13),
#  ('yet', 13),
#  ('near', 13),
#  ('missed', 13),
#  ('cancelled', 13),
#  ('fastpass', 13),
#  ('attitude', 13),
#  ('expectations', 13),
#  ('manor', 13),
#  ('care', 13),
#  ('disgusting', 13),
#  ('live', 13),
#  ('slightly', 12),
#  ('min', 12),
#  ('cost', 12),
#  ('opening', 12),
#  ('put', 12),
#  ('helpful', 12),
#  ('kept', 12),
#  ('store', 12),
#  ('pictures', 12),
#  ('hyperspace', 12),
#  ('sorry', 12),
#  ('mini', 12),
#  ('offer', 12),
#  ('fan', 12),
#  ('river', 12),
#  ('leave', 12),
#  ('finish', 12),
#  ('2nd', 12),
#  ('shut', 12),
#  ('enter', 12),
#  ('guess', 12),
#  ('hotels', 12),
#  ('pooh', 12),
#  ('low', 12),
#  ('round', 12),
#  ('use', 12),
#  ('cannot', 12),
#  ('tourist', 12),
#  ('age', 12),
#  ('till', 12),
#  ('huge', 12),
#  ('control', 12),
#  ('n', 12),
#  ('gets', 12),
#  ('shoving', 11),
#  ('free', 11),
#  ('note', 11),
#  ('renovation', 11),
#  ('enjoyable', 11),
#  ('thrill', 11),
#  ('snacks', 11),
#  ('friends', 11),
#  ('believe', 11),
#  ('work', 11),
#  ('wars', 11),
#  ('gulch', 11),
#  ('choice', 11),
#  ('behind', 11),
#  ('airport', 11),
#  ('season', 11),
#  ('options', 11),
#  ('forward', 11),
#  ('longer', 11),
#  ('typical', 11),
#  ('turned', 11),
#  ('station', 11),
#  ('older', 11),
#  ('entertainment', 11),
#  ('june', 11),
#  ('standing', 11),
#  ('winnie', 11),
#  ('empty', 11),
#  ('despite', 11),
#  ('aged', 11),
#  ('able', 11),
#  ('cheaper', 11),
#  ('cantonese', 11),
#  ('overcrowded', 11),
#  ('asia', 11),
#  ('complete', 11),
#  ('jump', 11),
#  ('families', 11),
#  ('mostly', 10),
#  ('problem', 10),
#  ('forget', 10),
#  ('atmosphere', 10),
#  ('easily', 10),
#  ('60', 10),
#  ('scary', 10),
#  ('sun', 10),
#  ('husband', 10),
#  ('stop', 10),
#  ('hand', 10),
#  ('wish', 10),
#  ('lightyear', 10),
#  ('coming', 10),
#  ('isnt', 10),
#  ('major', 10),
#  ('along', 10),
#  ('purchase', 10),
#  ('gone', 10),
#  ('wasted', 10),
#  ('surprised', 10),
#  ('someone', 10),
#  ('access', 10),
#  ('toys', 10),
#  ('course', 10),
#  ('teens', 10),
#  ('reason', 10),
#  ('planning', 10),
#  ('apart', 10),
#  ('absolutely', 10),
#  ('add', 10),
#  ('started', 10),
#  ('meant', 10),
#  ('available', 10),
#  ('bag', 10),
#  ('american', 10),
#  ('similar', 10),
#  ('tiny', 10),
#  ('fine', 10),
#  ('fire', 10),
#  ('five', 10),
#  ('review', 10),
#  ('members', 10),
#  ('cars', 10),
#  ('opened', 10),
#  ('childhood', 10),
#  ('umbrella', 10),
#  ('highlight', 10),
#  ('toddler', 10),
#  ('word', 10),
#  ('tell', 10),
#  ('tour', 10),
#  ('walked', 10),
#  ('bother', 10),
#  ('mean', 10),
#  ('speak', 10),
#  ('head', 10),
#  ('easy', 10),
#  ('imagine', 10),
#  ('game', 10),
#  ('weve', 10),
#  ('jumping', 10),
#  ('reach', 10),
#  ('mainly', 10),
#  ('fully', 10),
#  ('guests', 10),
#  ('haunted', 10),
#  ('standard', 10),
#  ('resort', 10),
#  ('working', 9),
#  ('walt', 9),
#  ('per', 9),
#  ('single', 9),
#  ('bottle', 9),
#  ('style', 9),
#  ('arent', 9),
#  ('experiences', 9),
#  ('anyway', 9),
#  ('allow', 9),
#  ('friend', 9),
#  ('11', 9),
#  ('minute', 9),
#  ('leaving', 9),
#  ('paying', 9),
#  ('local', 9),
#  ('knew', 9),
#  ('later', 9),
#  ('highly', 9),
#  ('studios', 9),
#  ('life', 9),
#  ('peak', 9),
#  ('book', 9),
#  ('prepared', 9),
#  ('majority', 9),
#  ('singapore', 9),
#  ('anywhere', 9),
#  ('closing', 9),
#  ('teenagers', 9),
#  ('toilets', 9),
#  ('plus', 9),
#  ('reviews', 9),
#  ('hard', 9),
#  ('lights', 9),
#  ('seriously', 9),
#  ('feeling', 9),
#  ('8', 9),
#  ('school', 9),
#  ('advice', 9),
#  ('ages', 9),
#  ('hall', 9),
#  ('shocked', 9),
#  ('outlets', 9),
#  ('rice', 9),
#  ('heavy', 9),
#  ('customers', 9),
#  ('help', 9),
#  ('list', 9),
#  ('shanghai', 9),
#  ('island', 9),
#  ('smoking', 9),
#  ('group', 9),
#  ('personal', 9),
#  ('13', 9),
#  ('offering', 9),
#  ('actions', 9),
#  ('takes', 9),
#  ('annoying', 9),
#  ('push', 9),
#  ('country', 9),
#  ('warning', 9),
#  ('id', 9),
#  ('que', 9),
#  ('basically', 8),
#  ('gift', 8),
#  ('fantastic', 8),
#  ('western', 8),
#  ('value', 8),
#  ('terms', 8),
#  ('including', 8),
#  ('stuff', 8),
#  ('missing', 8),
#  ('shopping', 8),
#  ('activities', 8),
#  ('type', 8),
#  ('scale', 8),
#  ('pre', 8),
#  ('purchased', 8),
#  ('lost', 8),
#  ('saying', 8),
#  ('chance', 8),
#  ('pricey', 8),
#  ('stated', 8),
#  ('firework', 8),
#  ('option', 8),
#  ('maintained', 8),
#  ('watching', 8),
#  ('december', 8),
#  ('outdoor', 8),
#  ('festival', 8),
#  ('weekend', 8),
#  ('private', 8),
#  ('encountered', 8),
#  ('comparing', 8),
#  ('gave', 8),
#  ('system', 8),
#  ('generally', 8),
#  ('stroller', 8),
#  ('bags', 8),
#  ('obviously', 8),
#  ('month', 8),
#  ('july', 8),
#  ('difficult', 8),
#  ('works', 8),
#  ('throughout', 8),
#  ('sit', 8),
#  ('relatively', 8),
#  ('opens', 8),
#  ('arrive', 8),
#  ('speaking', 8),
#  ('queueing', 8),
#  ('means', 8),
#  ('makes', 8),
#  ('pushed', 8),
#  ('toilet', 8),
#  ('police', 8),
#  ('reasons', 8),
#  ('special', 8),
#  ('happened', 8),
#  ('reached', 8),
#  ('spending', 8),
#  ('birthday', 8),
#  ('seats', 7),
#  ('happen', 7),
#  ('eating', 7),
#  ('fantasy', 7),
#  ('brought', 7),
#  ('cheap', 7),
#  ('discount', 7),
#  ('1030', 7),
#  ('paid', 7),
#  ('case', 7),
#  ('previous', 7),
#  ('third', 7),
#  ('autopia', 7),
#  ('april', 7),
#  ('loads', 7),
#  ('met', 7),
#  ('straight', 7),
#  ('klook', 7),
#  ('machine', 7),
#  ('play', 7),
#  ('nearly', 7),
#  ('foods', 7),
#  ('girl', 7),
#  ('ate', 7),
#  ('weekdays', 7),
#  ('quickly', 7),
#  ('needs', 7),
#  ('seeing', 7),
#  ('cast', 7),
#  ('ahead', 7),
#  ('otherwise', 7),
#  ('sadly', 7),
#  ('services', 7),
#  ('numerous', 7),
#  ('dirty', 7),
#  ('sunday', 7),
#  ('3pm', 7),
#  ('typhoon', 7),
#  ('august', 7),
#  ('mistake', 7),
#  ('yrs', 7),
#  ('changed', 7),
#  ('caught', 7),
#  ('tight', 7),
#  ('properly', 7),
#  ('singing', 7),
#  ('often', 7),
#  ('turn', 7),
#  ('ridiculously', 7),
#  ('cheapest', 7),
#  ('hope', 7),
#  ('seem', 7),
#  ('thinking', 7),
#  ('guest', 7),
#  ('supposed', 7),
#  ('saturday', 7),
#  ('trees', 7),
#  ('hit', 7),
#  ('8pm', 7),
#  ('view', 7),
#  ('indeed', 7),
#  ('possible', 7),
#  ('minimum', 7),
#  ('behavior', 7),
#  ('staffs', 7),
#  ('website', 7),
#  ('passes', 7),
#  ('disabled', 7),
#  ('smoke', 7),
#  ('ill', 7),
#  ('among', 7),
#  ('car', 7),
#  ('travel', 7),
#  ('goods', 7),
#  ('euro', 7),
#  ('added', 7),
#  ('50', 7),
#  ('studio', 7),
#  ('talking', 7),
#  ('decent', 7),
#  ('mickeys', 7),
#  ('poorly', 7),
#  ('perhaps', 7),
#  ('cater', 7),
#  ('built', 7),
#  ('encounter', 7),
#  ('choices', 6),
#  ('amount', 6),
#  ('exhausted', 6),
#  ('general', 6),
#  ('construction', 6),
#  ('finished', 6),
#  ('soon', 6),
#  ('aud', 6),
#  ('insane', 6),
#  ('shade', 6),
#  ('negative', 6),
#  ('recommended', 6),
#  ('today', 6),
#  ('march', 6),
#  ('loved', 6),
#  ('making', 6),
#  ('dressed', 6),
#  ('cinderella', 6),
#  ('philharmagic', 6),
#  ('amazing', 6),
#  ('simply', 6),
#  ('transportation', 6),
#  ('normal', 6),
#  ('refused', 6),
#  ('variety', 6),
#  ('choose', 6),
#  ('australia', 6),
#  ('sign', 6),
#  ('unpleasant', 6),
#  ('training', 6),
#  ('dumbo', 6),
#  ('watched', 6),
#  ('order', 6),
#  ('rip', 6),
#  ('ok', 6),
#  ('towards', 6),
#  ('rainy', 6),
#  ('daughters', 6),
#  ('member', 6),
#  ('25', 6),
#  ('3rd', 6),
#  ('dark', 6),
#  ('issue', 6),
#  ('site', 6),
#  ('customer', 6),
#  ('checked', 6),
#  ('excuse', 6),
#  ('covered', 6),
#  ('shorter', 6),
#  ('original', 6),
#  ('mid', 6),
#  ('10am', 6),
#  ('accept', 6),
#  ('truly', 6),
#  ('ironman', 6),
#  ('looked', 6),
#  ('movie', 6),
#  ('stitch', 6),
#  ('eurodisney', 6),
#  ('hate', 6),
#  ('lacked', 6),
#  ('hated', 6),
#  ('fans', 6),
#  ('1st', 6),
#  ('spoilt', 6),
#  ('havent', 6),
#  ('provide', 6),
#  ('selfie', 6),
#  ('music', 6),
#  ('slinky', 6),
#  ('dog', 6),
#  ('finally', 6),
#  ('air', 6),
#  ('addition', 6),
#  ('tip', 6),
#  ('located', 6),
#  ('included', 6),
#  ('catch', 6),
#  ('thus', 6),
#  ('impossible', 6),
#  ('selling', 6),
#  ('energy', 6),
#  ('states', 6),
#  ('house', 6),
#  ('guy', 6),
#  ('details', 6),
#  ('ask', 6),
#  ('dollars', 6),
#  ('badly', 6),
#  ('regret', 6),
#  ('asking', 6),
#  ('complained', 6),
#  ('unable', 6),
#  ('aimed', 6),
#  ('personally', 6),
#  ('run', 6),
#  ('manage', 6),
#  ('manners', 6),
#  ('14', 6),
#  ('visits', 6),
#  ('accessible', 6),
#  ('via', 6),
#  ('plain', 6),
#  ('nasty', 6),
#  ('follow', 6),
#  ('whats', 6),
#  ('beautiful', 6),
#  ('disneyworld', 6),
#  ('sale', 6),
#  ('surprise', 6),
#  ('gates', 6),
#  ('bigger', 6),
#  ('market', 6),
#  ('face', 6),
#  ('souvenir', 6),
#  ('green', 6),
#  ('limit', 6),
#  ('vip', 6),
#  ('consider', 6),
#  ('october', 6),
#  ('2012', 6),
#  ('bus', 6),
#  ('remember', 6),
#  ('lining', 6),
#  ('priced', 5),
#  ('building', 5),
#  ('dl', 5),
#  ('advise', 5),
#  ('deal', 5),
#  ('track', 5),
#  ('biggest', 5),
#  ('hollywood', 5),
#  ('charge', 5),
#  ('dinner', 5),
#  ('breakfast', 5),
#  ('trains', 5),
#  ('coz', 5),
#  ('surely', 5),
#  ('recent', 5),
#  ('quiet', 5),
#  ('tons', 5),
#  ('suited', 5),
#  ('heard', 5),
#  ('okay', 5),
#  ('super', 5),
#  ('floor', 5),
#  ('phone', 5),
#  ('wow', 5),
#  ('white', 5),
#  ('bar', 5),
#  ('specially', 5),
#  ('entering', 5),
#  ('requested', 5),
#  ('voucher', 5),
#  ('organised', 5),
#  ('showed', 5),
#  ('retail', 5),
#  ('change', 5),
#  ('halal', 5),
#  ('lands', 5),
#  ('moana', 5),
#  ('subway', 5),
#  ('america', 5),
#  ('ball', 5),
#  ('shame', 5),
#  ('display', 5),
#  ('fees', 5),
#  ('move', 5),
#  ('opportunity', 5),
#  ('coffee', 5),
#  ('prior', 5),
#  ('tasteless', 5),
#  ('minimal', 5),
#  ...]

# %%
word_counts_df = pd.DataFrame(word_counts.most_common(50))
word_counts_df.columns = ['word', 'counts']

# %%
plt.figure(figsize =(10,8))
sns.barplot(x = 'counts', y = 'word', data = word_counts_df)
# Out:
# <AxesSubplot:xlabel='counts', ylabel='word'>

# %%
# 시각화 
wordcloud = WordCloud(background_color = 'white',
                      max_words = 100,
                      relative_scaling = 0.3,
                      width = 800,
                      height = 400).generate_from_frequencies(word_counts)
plt.figure(figsize = (15,10))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %%
N_C = df[(df['Branch']=='Disneyland_California') & (df['Analysis']=='Negative')]
N_C
# Out:
#        Rating Reviewer_Location  \
# 9636        1     United States
# 9642        2    United Kingdom
# 9687        1         Australia
# 9701        1     United States
# 9703        5            Canada
# ...       ...               ...
# 28909       3     United States
# 28957       4     United States
# 28960       1     United States
# 28962       1     United States
# 29023       1     United States
#
#                                              Review_Text  \
# 9636   [, disneyland, several, times, past, 3, decade...
# 9642   [partner, paid, 149, tickets, park, partner, w...
# 9687   [really, disappointed, disneylandold, tired, c...
# 9701   [came, anniversary, trip, rides, extremely, lo...
# 9703   [truly, happiest, place, earth, pay, money, ge...
# ...                                                  ...
# 28909  [first, visit, disneyland, since, 7, years, ol...
# 28957  [would, like, clarify, disneyland, older, , di...
# 28960  [august, 4, 2005hello, single, mom, widow, one...
# 28962  [disneyland, everybody, factwe, knew, school, ...
# 29023  [never, againwhat, horrible, experience, worst...
#
#                       Branch  Polarity  Analysis
# 9636   Disneyland_California -0.068937  Negative
# 9642   Disneyland_California -0.010714  Negative
# 9687   Disneyland_California -0.037778  Negative
# 9701   Disneyland_California -0.202747  Negative
# 9703   Disneyland_California -0.023438  Negative
# ...                      ...       ...       ...
# 28909  Disneyland_California -0.015317  Negative
# 28957  Disneyland_California -0.093889  Negative
# 28960  Disneyland_California -0.037338  Negative
# 28962  Disneyland_California -0.088942  Negative
# 29023  Disneyland_California -0.126190  Negative
#
# [1531 rows x 6 columns]

# %%
from collections import Counter
word_counts = Counter()
N_C['Review_Text'].apply(lambda x: word_counts.update(x))
count = word_counts.most_common()
count
# Out:
# [('', 1955),
#  ('park', 1247),
#  ('disneyland', 1019),
#  ('disney', 883),
#  ('rides', 864),
#  ('day', 795),
#  ('get', 748),
#  ('time', 714),
#  ('go', 612),
#  ('people', 584),
#  ('ride', 578),
#  ('one', 501),
#  ('line', 463),
#  ('lines', 447),
#  ('place', 423),
#  ('long', 414),
#  ('would', 412),
#  ('wait', 411),
#  ('like', 378),
#  ('went', 360),
#  ('food', 351),
#  ('expensive', 341),
#  ('kids', 341),
#  ('back', 320),
#  ('even', 319),
#  ('crowded', 312),
#  ('times', 296),
#  ('visit', 290),
#  ('pass', 289),
#  ('2', 288),
#  ('see', 286),
#  ('disappointed', 285),
#  ('us', 282),
#  ('could', 254),
#  ('dont', 254),
#  ('closed', 253),
#  ('crowds', 253),
#  ('way', 252),
#  ('much', 248),
#  ('going', 248),
#  ('never', 246),
#  ('world', 243),
#  ('really', 242),
#  ('money', 240),
#  ('got', 240),
#  ('minutes', 238),
#  ('year', 238),
#  ('around', 226),
#  ('fast', 225),
#  ('little', 225),
#  ('hours', 224),
#  ('experience', 224),
#  ('many', 220),
#  ('family', 218),
#  ('years', 217),
#  ('california', 209),
#  ('bad', 209),
#  ('3', 207),
#  ('parade', 206),
#  ('also', 205),
#  ('small', 203),
#  ('hour', 203),
#  ('two', 200),
#  ('tickets', 193),
#  ('trip', 190),
#  ('days', 188),
#  ('mountain', 187),
#  ('still', 185),
#  ('every', 181),
#  ('take', 179),
#  ('parks', 176),
#  ('lot', 175),
#  ('first', 172),
#  ('least', 169),
#  ('old', 169),
#  ('4', 167),
#  ('well', 167),
#  ('didnt', 167),
#  ('last', 165),
#  ('fun', 165),
#  ('attractions', 162),
#  ('told', 161),
#  ('earth', 161),
#  ('staff', 160),
#  ('5', 158),
#  ('waiting', 154),
#  ('make', 153),
#  ('always', 151),
#  ('happiest', 145),
#  ('everything', 145),
#  ('know', 144),
#  ('adventure', 142),
#  ('think', 142),
#  ('say', 141),
#  ('children', 138),
#  ('fireworks', 134),
#  ('another', 133),
#  ('passes', 133),
#  ('characters', 131),
#  ('spent', 130),
#  ('less', 129),
#  ('need', 128),
#  ('ticket', 128),
#  ('1', 127),
#  ('come', 126),
#  ('since', 125),
#  ('space', 124),
#  ('walk', 124),
#  ('visited', 123),
#  ('want', 120),
#  ('prices', 117),
#  ('big', 117),
#  ('early', 115),
#  ('10', 114),
#  ('cast', 113),
#  ('said', 112),
#  ('took', 112),
#  ('worth', 111),
#  ('find', 109),
#  ('getting', 109),
#  ('disappointing', 108),
#  ('busy', 108),
#  ('love', 107),
#  ('waited', 103),
#  ('made', 103),
#  ('things', 101),
#  ('ever', 101),
#  ('left', 100),
#  ('price', 99),
#  ('next', 98),
#  ('pay', 98),
#  ('water', 97),
#  ('cant', 97),
#  ('use', 96),
#  ('night', 96),
#  ('everyone', 95),
#  ('wanted', 95),
#  ('rude', 95),
#  ('great', 94),
#  ('nothing', 93),
#  ('new', 93),
#  ('thing', 92),
#  ('due', 92),
#  ('must', 92),
#  ('half', 92),
#  ('members', 92),
#  ('show', 91),
#  ('parking', 91),
#  ('couldnt', 90),
#  ('week', 90),
#  ('enough', 89),
#  ('spend', 89),
#  ('fastpass', 88),
#  ('though', 88),
#  ('good', 86),
#  ('better', 86),
#  ('crazy', 86),
#  ('stand', 85),
#  ('service', 84),
#  ('30', 84),
#  ('paid', 83),
#  ('found', 83),
#  ('area', 83),
#  ('pirates', 83),
#  ('past', 82),
#  ('three', 82),
#  ('felt', 82),
#  ('season', 82),
#  ('worst', 81),
#  ('hard', 81),
#  ('disappointment', 80),
#  ('wasnt', 80),
#  ('walking', 80),
#  ('ridiculous', 79),
#  ('however', 79),
#  ('broke', 78),
#  ('florida', 78),
#  ('bring', 77),
#  ('crowd', 77),
#  ('several', 76),
#  ('magic', 76),
#  ('per', 76),
#  ('almost', 76),
#  ('queues', 76),
#  ('without', 75),
#  ('expected', 75),
#  ('break', 75),
#  ('christmas', 75),
#  ('main', 75),
#  ('let', 75),
#  ('20', 75),
#  ('saw', 74),
#  ('something', 74),
#  ('thought', 74),
#  ('star', 74),
#  ('jones', 74),
#  ('land', 74),
#  ('front', 73),
#  ('45', 73),
#  ('hotel', 72),
#  ('lots', 72),
#  ('waste', 72),
#  ('theme', 72),
#  ('recommend', 71),
#  ('different', 71),
#  ('broken', 71),
#  ('minute', 70),
#  ('wrong', 70),
#  ('especially', 70),
#  ('leave', 69),
#  ('came', 69),
#  ('enjoy', 69),
#  ('done', 69),
#  ('anything', 69),
#  ('sad', 69),
#  ('actually', 69),
#  ('terrible', 69),
#  ('15', 68),
#  ('walt', 68),
#  ('indiana', 68),
#  ('son', 67),
#  ('feel', 67),
#  ('whole', 66),
#  ('keep', 66),
#  ('hopper', 66),
#  ('poor', 65),
#  ('buy', 65),
#  ('standing', 65),
#  ('wont', 65),
#  ('part', 64),
#  ('try', 64),
#  ('asked', 64),
#  ('used', 64),
#  ('may', 64),
#  ('move', 64),
#  ('return', 63),
#  ('mickey', 63),
#  ('haunted', 63),
#  ('im', 63),
#  ('away', 62),
#  ('holiday', 62),
#  ('maybe', 62),
#  ('6', 62),
#  ('visiting', 62),
#  ('high', 62),
#  ('trying', 62),
#  ('tired', 61),
#  ('sure', 61),
#  ('daughter', 61),
#  ('magical', 61),
#  ('rest', 60),
#  ('horrible', 60),
#  ('cost', 60),
#  ('definitely', 60),
#  ('street', 60),
#  ('waits', 60),
#  ('either', 59),
#  ('avoid', 59),
#  ('orlando', 59),
#  ('number', 59),
#  ('end', 59),
#  ('bit', 59),
#  ('young', 59),
#  ('morning', 58),
#  ('give', 58),
#  ('impossible', 58),
#  ('gone', 58),
#  ('expect', 58),
#  ('open', 57),
#  ('child', 57),
#  ('ive', 57),
#  ('point', 57),
#  ('couple', 56),
#  ('matterhorn', 56),
#  ('help', 56),
#  ('guests', 56),
#  ('disneyworld', 56),
#  ('halloween', 56),
#  ('annual', 56),
#  ('longer', 55),
#  ('amount', 55),
#  ('splash', 55),
#  ('overpriced', 55),
#  ('seems', 55),
#  ('thats', 55),
#  ('later', 54),
#  ('100', 54),
#  ('seemed', 54),
#  ('stroller', 54),
#  ('packed', 54),
#  ('full', 53),
#  ('quite', 53),
#  ('work', 53),
#  ('ones', 53),
#  ('places', 52),
#  ('universal', 52),
#  ('already', 52),
#  ('member', 52),
#  ('awful', 52),
#  ('person', 52),
#  ('coming', 52),
#  ('four', 52),
#  ('employees', 51),
#  ('finally', 51),
#  ('adults', 51),
#  ('spring', 51),
#  ('unfortunately', 51),
#  ('else', 51),
#  ('right', 51),
#  ('yes', 51),
#  ('summer', 51),
#  ('average', 50),
#  ('sit', 50),
#  ('castle', 50),
#  ('customer', 50),
#  ('wife', 50),
#  ('stay', 50),
#  ('tried', 49),
#  ('queue', 49),
#  ('check', 49),
#  ('late', 49),
#  ('difficult', 49),
#  ('40', 49),
#  ('everywhere', 49),
#  ('kid', 49),
#  ('school', 49),
#  ('system', 49),
#  ('hot', 49),
#  ('strollers', 48),
#  ('look', 48),
#  ('single', 48),
#  ('start', 48),
#  ('party', 48),
#  ('major', 47),
#  ('security', 47),
#  ('tell', 47),
#  ('cars', 47),
#  ('plan', 47),
#  ('werent', 47),
#  ('watch', 46),
#  ('8', 46),
#  ('working', 46),
#  ('needs', 46),
#  ('ago', 46),
#  ('evening', 46),
#  ('seen', 45),
#  ('sorry', 45),
#  ('plus', 45),
#  ('side', 45),
#  ('shut', 45),
#  ('able', 45),
#  ('entrance', 45),
#  ('weekend', 45),
#  ('drinks', 45),
#  ('hate', 44),
#  ('extremely', 44),
#  ('instead', 44),
#  ('pretty', 44),
#  ('dirty', 44),
#  ('7', 44),
#  ('character', 44),
#  ('eat', 44),
#  ('save', 44),
#  ('app', 44),
#  ('restaurants', 44),
#  ('life', 44),
#  ('compared', 44),
#  ('allowed', 43),
#  ('disabled', 43),
#  ('second', 43),
#  ('mansion', 43),
#  ('lunch', 43),
#  ('gate', 42),
#  ('makes', 42),
#  ('huge', 42),
#  ('started', 42),
#  ('behind', 42),
#  ('best', 42),
#  ('doesnt', 42),
#  ('youre', 42),
#  ('enjoyed', 42),
#  ('enter', 41),
#  ('course', 41),
#  ('entry', 41),
#  ('far', 41),
#  ('close', 41),
#  ('husband', 41),
#  ('decided', 41),
#  ('shows', 41),
#  ('arrived', 41),
#  ('room', 41),
#  ('thunder', 41),
#  ('care', 40),
#  ('run', 40),
#  ('knew', 40),
#  ('problem', 40),
#  ('using', 39),
#  ('families', 39),
#  ('employee', 39),
#  ('reason', 39),
#  ('etc', 39),
#  ('miserable', 39),
#  ('extra', 38),
#  ('priced', 38),
#  ('min', 38),
#  ('probably', 38),
#  ('mean', 38),
#  ('90', 38),
#  ('outrageous', 38),
#  ('dollars', 38),
#  ('cold', 38),
#  ('train', 38),
#  ('cannot', 38),
#  ('walked', 37),
#  ('nice', 37),
#  ('inside', 37),
#  ('total', 37),
#  ('wars', 37),
#  ('given', 37),
#  ('smaller', 37),
#  ('attraction', 37),
#  ('overall', 37),
#  ('someone', 37),
#  ('paying', 36),
#  ('entire', 36),
#  ('others', 36),
#  ('put', 36),
#  ('admission', 36),
#  ('happened', 36),
#  ('live', 36),
#  ('short', 36),
#  ('areas', 36),
#  ('parents', 36),
#  ('twice', 36),
#  ('running', 36),
#  ('caribbean', 36),
#  ('worse', 36),
#  ('heat', 36),
#  ('changed', 36),
#  ('9', 35),
#  ('studios', 35),
#  ('absolutely', 35),
#  ('making', 35),
#  ('taking', 35),
#  ('anyone', 35),
#  ('usually', 35),
#  ('planning', 35),
#  ('meal', 35),
#  ('outside', 35),
#  ('looking', 35),
#  ('guess', 35),
#  ('understand', 34),
#  ('stop', 34),
#  ('called', 34),
#  ('ended', 34),
#  ('downtown', 34),
#  ('holidays', 34),
#  ('car', 33),
#  ('simply', 33),
#  ('managed', 33),
#  ('vacation', 33),
#  ('12', 33),
#  ('although', 33),
#  ('house', 33),
#  ('anaheim', 33),
#  ('blast', 33),
#  ('seem', 33),
#  ('friendly', 33),
#  ('become', 32),
#  ('opened', 32),
#  ('october', 32),
#  ('daughters', 32),
#  ('possible', 32),
#  ('wish', 32),
#  ('snacks', 32),
#  ('offer', 32),
#  ('along', 32),
#  ('photo', 31),
#  ('construction', 31),
#  ('truly', 31),
#  ('gave', 31),
#  ('60', 31),
#  ('online', 31),
#  ('turned', 31),
#  ('ill', 31),
#  ('plenty', 31),
#  ('meet', 31),
#  ('review', 31),
#  ('totally', 31),
#  ('parades', 31),
#  ('except', 31),
#  ('slow', 31),
#  ('yet', 31),
#  ('picture', 30),
#  ('large', 30),
#  ('happy', 30),
#  ('spending', 30),
#  ('looked', 30),
#  ('limit', 30),
#  ('taken', 30),
#  ('please', 30),
#  ('peak', 30),
#  ('prepared', 30),
#  ('stood', 30),
#  ('anymore', 30),
#  ('wouldnt', 30),
#  ('home', 30),
#  ('resort', 30),
#  ('quality', 30),
#  ('frustrating', 30),
#  ('control', 30),
#  ('fantasmic', 29),
#  ('original', 29),
#  ('issues', 29),
#  ('annoying', 29),
#  ('available', 29),
#  ('la', 29),
#  ('value', 29),
#  ('change', 29),
#  ('insane', 29),
#  ('restaurant', 29),
#  ('lost', 29),
#  ('age', 29),
#  ('often', 29),
#  ('usual', 29),
#  ('mid', 29),
#  ('pm', 29),
#  ('hardly', 28),
#  ('overcrowded', 28),
#  ('gets', 28),
#  ('issue', 28),
#  ('bathrooms', 28),
#  ('drink', 28),
#  ('supposed', 28),
#  ('cut', 28),
#  ('loved', 28),
#  ('souvenirs', 27),
#  ('purchase', 27),
#  ('brought', 27),
#  ('photos', 27),
#  ('set', 27),
#  ('maintenance', 27),
#  ('multiple', 27),
#  ('anywhere', 27),
#  ('barely', 27),
#  ('special', 27),
#  ('kept', 27),
#  ('wasted', 26),
#  ('throughout', 26),
#  ('bought', 26),
#  ('rode', 26),
#  ('mind', 26),
#  ('rather', 26),
#  ('older', 26),
#  ('fastpasses', 26),
#  ('problems', 26),
#  ('spot', 26),
#  ('top', 26),
#  ('heard', 26),
#  ('soon', 26),
#  ('free', 26),
#  ('anniversary', 25),
#  ('peter', 25),
#  ('50', 25),
#  ('low', 25),
#  ('stopped', 25),
#  ('light', 25),
#  ('opening', 25),
#  ('mins', 25),
#  ('unless', 25),
#  ('today', 25),
#  ('traffic', 25),
#  ('together', 25),
#  ('near', 25),
#  ('management', 25),
#  ('guest', 25),
#  ('literally', 25),
#  ('id', 25),
#  ('nearly', 25),
#  ('boring', 25),
#  ('afternoon', 25),
#  ('ask', 25),
#  ('shuttle', 25),
#  ('middle', 25),
#  ('missed', 25),
#  ('matter', 25),
#  ('pictures', 25),
#  ('weve', 25),
#  ('helpful', 25),
#  ('frustrated', 25),
#  ('moving', 25),
#  ('arent', 25),
#  ('complaint', 25),
#  ('seeing', 24),
#  ('25', 24),
#  ('saying', 24),
#  ('including', 24),
#  ('bottle', 24),
#  ('shops', 24),
#  ('wheelchair', 24),
#  ('ca', 24),
#  ('fan', 23),
#  ('pan', 23),
#  ('fact', 23),
#  ('scary', 23),
#  ('months', 23),
#  ('tours', 23),
#  ('entertainment', 23),
#  ('birthday', 23),
#  ('travel', 23),
#  ('remember', 23),
#  ('clean', 23),
#  ('might', 23),
#  ('ate', 23),
#  ('pizza', 23),
#  ('kingdom', 23),
#  ('roller', 23),
#  ('excited', 23),
#  ('ups', 23),
#  ('shame', 23),
#  ('group', 23),
#  ('disneys', 23),
#  ('five', 23),
#  ('dinner', 23),
#  ('forward', 22),
#  ('across', 22),
#  ('tuesday', 22),
#  ('add', 22),
#  ('noticed', 22),
#  ('biggest', 22),
#  ('sadly', 22),
#  ('amusement', 22),
#  ('takes', 22),
#  ('allow', 22),
#  ('favorite', 22),
#  ('phone', 22),
#  ('charge', 22),
#  ('stayed', 22),
#  ('monday', 22),
#  ('popular', 22),
#  ('customers', 21),
#  ('access', 21),
#  ('list', 21),
#  ('finding', 21),
#  ('amazing', 21),
#  ('process', 21),
#  ('local', 21),
#  ('breaking', 21),
#  ('sometimes', 21),
#  ('havent', 21),
#  ('mouse', 21),
#  ('returned', 21),
#  ('limited', 21),
#  ('means', 21),
#  ('afford', 21),
#  ('recent', 21),
#  ('ages', 21),
#  ('completely', 21),
#  ('thousands', 21),
#  ('isnt', 21),
#  ('real', 21),
#  ('thinking', 21),
#  ('paris', 21),
#  ('perhaps', 21),
#  ('heart', 21),
#  ('discount', 20),
#  ('complete', 20),
#  ('seriously', 20),
#  ('options', 20),
#  ('planned', 20),
#  ('joke', 20),
#  ('closing', 20),
#  ('shade', 20),
#  ('cancelled', 20),
#  ('shoulder', 20),
#  ('weather', 20),
#  ('bother', 20),
#  ('wednesday', 20),
#  ('stuck', 20),
#  ('april', 20),
#  ('adult', 19),
#  ('lady', 19),
#  ('super', 19),
#  ('hit', 19),
#  ('city', 19),
#  ('recently', 19),
#  ('oh', 19),
#  ('february', 19),
#  ('january', 19),
#  ('friends', 19),
#  ('returning', 19),
#  ('needed', 19),
#  ('sun', 19),
#  ('town', 19),
#  ('grown', 19),
#  ('dark', 19),
#  ('within', 19),
#  ('theres', 19),
#  ('believe', 19),
#  ('princess', 19),
#  ('visits', 19),
#  ('turn', 19),
#  ('nemo', 19),
#  ('nasty', 19),
#  ('locals', 19),
#  ('60th', 19),
#  ('unhappy', 18),
#  ('ahead', 18),
#  ('ruined', 18),
#  ('asking', 18),
#  ('max', 18),
#  ('snow', 18),
#  ('kind', 18),
#  ('stuff', 18),
#  ('pack', 18),
#  ('third', 18),
#  ('sold', 18),
#  ('electric', 18),
#  ('otherwise', 18),
#  ('order', 18),
#  ('purchased', 18),
#  ('coaster', 18),
#  ('youll', 18),
#  ('certainly', 18),
#  ('read', 18),
#  ('staying', 18),
#  ('bag', 18),
#  ('monorail', 18),
#  ('size', 18),
#  ('miss', 18),
#  ('upon', 18),
#  ('pick', 18),
#  ('met', 18),
#  ('gates', 18),
#  ('event', 18),
#  ('eating', 18),
#  ('moment', 18),
#  ('blue', 18),
#  ('highly', 17),
#  ('breakfast', 17),
#  ('boy', 17),
#  ('six', 17),
#  ('relations', 17),
#  ('treat', 17),
#  ('expecting', 17),
#  ('exit', 17),
#  ('southern', 17),
#  ('site', 17),
#  ('incredibly', 17),
#  ('weekday', 17),
#  ('visitors', 17),
#  ('lack', 17),
#  ('forever', 17),
#  ('non', 17),
#  ('70', 17),
#  ('shorter', 17),
#  ('fee', 17),
#  ('suggest', 17),
#  ('signs', 17),
#  ('weekends', 17),
#  ('imagine', 17),
#  ('worked', 17),
#  ('mention', 17),
#  ('july', 17),
#  ('riding', 17),
#  ('selling', 17),
#  ('minnie', 17),
#  ('cutting', 17),
#  ('princesses', 17),
#  ('previous', 17),
#  ('watching', 17),
#  ('happen', 17),
#  ('chance', 17),
#  ('shocked', 17),
#  ('bags', 17),
#  ('capacity', 16),
#  ('rip', 16),
#  ('que', 16),
#  ('memories', 16),
#  ('head', 16),
#  ('ok', 16),
#  ('ridiculously', 16),
#  ('maxpass', 16),
#  ('bus', 16),
#  ('job', 16),
#  ('tram', 16),
#  ('minimum', 16),
#  ('table', 16),
#  ('grandchildren', 16),
#  ('book', 16),
#  ('wdw', 16),
#  ('choice', 16),
#  ('booked', 16),
#  ('situation', 16),
#  ('80', 16),
#  ('cruise', 16),
#  ('bored', 16),
#  ('childhood', 16),
#  ('experienced', 16),
#  ('gotten', 16),
#  ('anyway', 16),
#  ('onto', 16),
#  ('teenagers', 16),
#  ('watched', 16),
#  ('17', 16),
#  ('skip', 16),
#  ('surprised', 16),
#  ('call', 16),
#  ('march', 16),
#  ('offered', 16),
#  ('game', 16),
#  ('leaving', 16),
#  ('friday', 16),
#  ('business', 16),
#  ('negative', 15),
#  ('card', 15),
#  ('talk', 15),
#  ('teens', 15),
#  ('comes', 15),
#  ('dream', 15),
#  ('treated', 15),
#  ('month', 15),
#  ('rider', 15),
#  ('decorations', 15),
#  ('restrooms', 15),
#  ('closures', 15),
#  ('mistake', 15),
#  ('period', 15),
#  ('tomorrowland', 15),
#  ('typical', 15),
#  ('hold', 15),
#  ('sign', 15),
#  ('hey', 15),
#  ('nearby', 15),
#  ('mickeys', 15),
#  ('advance', 15),
#  ('slightly', 15),
#  ('sunday', 15),
#  ('1st', 15),
#  ('track', 15),
#  ('fault', 15),
#  ('talking', 15),
#  ('orleans', 15),
#  ('disgusting', 15),
#  ('giving', 15),
#  ('dog', 15),
#  ('bucks', 15),
#  ('idea', 15),
#  ('complaining', 15),
#  ('lined', 15),
#  ('quickly', 15),
#  ('thru', 15),
#  ('store', 15),
#  ('fl', 15),
#  ('ready', 15),
#  ('taste', 15),
#  ('11', 14),
#  ('stick', 14),
#  ('forget', 14),
#  ('regular', 14),
#  ('lineups', 14),
#  ('lifetime', 14),
#  ('buzz', 14),
#  ('man', 14),
#  ('whether', 14),
#  ('sick', 14),
#  ('glad', 14),
#  ('corn', 14),
#  ('white', 14),
#  ('fire', 14),
#  ('hated', 14),
#  ('meals', 14),
#  ('garage', 14),
#  ('expectations', 14),
#  ('says', 14),
#  ('buying', 14),
#  ('music', 14),
#  ('comparison', 14),
#  ('consider', 14),
#  ('ice', 14),
#  ('poorly', 14),
#  ('traveling', 14),
#  ('roped', 14),
#  ('refused', 14),
#  ('reviews', 14),
#  ('fantasyland', 14),
#  ('drive', 14),
#  ('eventually', 14),
#  ('saturday', 14),
#  ('usa', 14),
#  ('longest', 14),
#  ('deal', 14),
#  ('refund', 14),
#  ('crap', 14),
#  ('constantly', 14),
#  ('nightmare', 14),
#  ('entering', 14),
#  ('showed', 14),
#  ('added', 14),
#  ('booth', 14),
#  ('color', 14),
#  ('clearly', 14),
#  ('shopping', 14),
#  ('changes', 14),
#  ('chicken', 14),
#  ('obviously', 14),
#  ('sort', 14),
#  ('seats', 14),
#  ('saved', 14),
#  ('attitude', 14),
#  ('sitting', 14),
#  ('wed', 14),
#  ('queuing', 14),
#  ('story', 14),
#  ('14', 14),
#  ('began', 14),
#  ('tons', 13),
#  ('works', 13),
#  ('stars', 13),
#  ('unable', 13),
#  ('rate', 13),
#  ('grave', 13),
#  ('picked', 13),
#  ('ordered', 13),
#  ('mostly', 13),
#  ('australia', 13),
#  ('massive', 13),
#  ('goes', 13),
#  ('hall', 13),
#  ('ran', 13),
#  ('round', 13),
#  ('burger', 13),
#  ('thank', 13),
#  ('experiences', 13),
#  ('folks', 13),
#  ('jungle', 13),
#  ('guy', 13),
#  ('bigger', 13),
#  ('pushed', 13),
#  ('view', 13),
#  ('considering', 13),
#  ('various', 13),
#  ('name', 13),
#  ('corporate', 13),
#  ('stupid', 13),
#  ('knotts', 13),
#  ('alice', 13),
#  ('seating', 13),
#  ('35', 13),
#  ('apparently', 13),
#  ('thursday', 13),
#  ('garbage', 13),
#  ('entered', 13),
#  ('nights', 13),
#  ('hand', 13),
#  ('numerous', 13),
#  ('directed', 13),
#  ('opinion', 13),
#  ('feeling', 13),
#  ('checked', 13),
#  ('navigate', 13),
#  ('holders', 13),
#  ('besides', 13),
#  ('costs', 13),
#  ('till', 13),
#  ('lights', 13),
#  ('dangerous', 13),
#  ('fans', 13),
#  ('arrive', 13),
#  ('unbelievable', 13),
#  ('empty', 13),
#  ('december', 13),
#  ('example', 13),
#  ('grad', 13),
#  ('advantage', 13),
#  ('greedy', 12),
#  ('double', 12),
#  ('pre', 12),
#  ('telling', 12),
#  ('gift', 12),
#  ('fantastic', 12),
#  ('dozen', 12),
#  ('disability', 12),
#  ('meeting', 12),
#  ('smile', 12),
#  ('classic', 12),
#  ('fees', 12),
#  ('girls', 12),
#  ('opens', 12),
#  ('currently', 12),
#  ('letting', 12),
#  ('somewhere', 12),
#  ('awhile', 12),
#  ('girl', 12),
#  ('wow', 12),
#  ('adventureland', 12),
#  ('hamburger', 12),
#  ('dining', 12),
#  ('realize', 12),
#  ('despite', 12),
#  ...]

# %%
word_counts_df2 = pd.DataFrame(word_counts.most_common(50))
word_counts_df2.columns = ['word', 'counts']

# %%
plt.figure(figsize =(10,8))
sns.barplot(x = 'counts', y = 'word', data = word_counts_df2)
# Out:
# <AxesSubplot:xlabel='counts', ylabel='word'>

# %%
# 시각화 
wordcloud = WordCloud(background_color = 'white',
                      max_words = 100,
                      relative_scaling = 0.3,
                      width = 800,
                      height = 400).generate_from_frequencies(word_counts)
plt.figure(figsize = (15,10))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %%
N_P = df[(df['Branch']=='Disneyland_Paris') & (df['Analysis']=='Negative')]
N_P
# Out:
#        Rating Reviewer_Location  \
# 29034       2            Greece
# 29038       5             Malta
# 29041       5      Saudi Arabia
# 29050       5            Israel
# 29053       1    United Kingdom
# ...       ...               ...
# 42602       2    United Kingdom
# 42633       2    United Kingdom
# 42635       1     United States
# 42636       2       Switzerland
# 42647       2     United States
#
#                                              Review_Text            Branch  \
# 29034  [booked, tickets, line, disneyland, something,...  Disneyland_Paris
# 29038  [place, everyone, deserves, go, least, life, t...  Disneyland_Paris
# 29041  [twice, , grandson, never, give, grandsons, ne...  Disneyland_Paris
# 29050  [traveled, december, day, bit, rainy, less, cr...  Disneyland_Paris
# 29053  [shame, park, carry, name, disney, build, plac...  Disneyland_Paris
# ...                                                  ...               ...
# 42602  [expected, visited, 2, american, theme, parks,...  Disneyland_Paris
# 42633  [weve, come, back, couple, days, eurodisney, a...  Disneyland_Paris
# 42635  [spent, three, days, disneyland, paris, resort...  Disneyland_Paris
# 42636  [parades, great, bathrooms, filthy, , could, d...  Disneyland_Paris
# 42647  [would, recommend, going, disney, resorts, one...  Disneyland_Paris
#
#        Polarity  Analysis
# 29034 -0.016304  Negative
# 29038 -0.150000  Negative
# 29041 -0.216667  Negative
# 29050 -0.191667  Negative
# 29053 -0.027778  Negative
# ...         ...       ...
# 42602 -0.107143  Negative
# 42633 -0.034722  Negative
# 42635 -0.065000  Negative
# 42636 -0.097222  Negative
# 42647 -0.133333  Negative
#
# [1514 rows x 6 columns]

# %%
from collections import Counter
word_counts = Counter()
N_P['Review_Text'].apply(lambda x: word_counts.update(x))
count = word_counts.most_common()
count
# Out:
# [('', 2949),
#  ('disney', 1597),
#  ('park', 1590),
#  ('rides', 1318),
#  ('food', 828),
#  ('day', 826),
#  ('get', 785),
#  ('time', 778),
#  ('one', 758),
#  ('would', 737),
#  ('go', 731),
#  ('disneyland', 721),
#  ('paris', 673),
#  ('staff', 613),
#  ('ride', 602),
#  ('people', 597),
#  ('closed', 581),
#  ('us', 511),
#  ('queues', 499),
#  ('expensive', 492),
#  ('2', 488),
#  ('even', 477),
#  ('queue', 463),
#  ('like', 458),
#  ('children', 433),
#  ('parks', 426),
#  ('back', 413),
#  ('went', 413),
#  ('long', 405),
#  ('around', 392),
#  ('see', 387),
#  ('kids', 382),
#  ('minutes', 368),
#  ('visit', 367),
#  ('really', 366),
#  ('wait', 364),
#  ('money', 351),
#  ('place', 345),
#  ('characters', 340),
#  ('3', 334),
#  ('disappointed', 333),
#  ('also', 331),
#  ('could', 325),
#  ('dont', 324),
#  ('hour', 324),
#  ('attractions', 308),
#  ('year', 305),
#  ('much', 301),
#  ('times', 299),
#  ('experience', 298),
#  ('hotel', 295),
#  ('days', 290),
#  ('bad', 287),
#  ('two', 287),
#  ('hours', 285),
#  ('never', 279),
#  ('got', 275),
#  ('fast', 274),
#  ('waiting', 269),
#  ('florida', 264),
#  ('little', 260),
#  ('going', 256),
#  ('half', 253),
#  ('visited', 252),
#  ('lot', 248),
#  ('small', 243),
#  ('tickets', 242),
#  ('many', 240),
#  ('good', 239),
#  ('didnt', 238),
#  ('take', 234),
#  ('parade', 233),
#  ('service', 232),
#  ('well', 231),
#  ('poor', 231),
#  ('4', 229),
#  ('told', 224),
#  ('french', 223),
#  ('old', 221),
#  ('rude', 220),
#  ('pass', 210),
#  ('way', 208),
#  ('say', 207),
#  ('trip', 204),
#  ('line', 203),
#  ('big', 202),
#  ('cold', 201),
#  ('still', 201),
#  ('think', 200),
#  ('5', 199),
#  ('first', 196),
#  ('family', 194),
#  ('mountain', 194),
#  ('open', 194),
#  ('years', 190),
#  ('every', 189),
#  ('show', 187),
#  ('least', 183),
#  ('1', 183),
#  ('find', 179),
#  ('better', 177),
#  ('everything', 173),
#  ('need', 171),
#  ('smoking', 168),
#  ('world', 165),
#  ('lines', 164),
#  ('know', 164),
#  ('another', 164),
#  ('restaurants', 163),
#  ('euros', 161),
#  ('last', 160),
#  ('make', 159),
#  ('queuing', 158),
#  ('disappointing', 156),
#  ('said', 155),
#  ('bit', 154),
#  ('made', 154),
#  ('found', 153),
#  ('due', 152),
#  ('want', 151),
#  ('whole', 149),
#  ('spent', 148),
#  ('ticket', 147),
#  ('train', 147),
#  ('however', 147),
#  ('nothing', 144),
#  ('eat', 143),
#  ('magic', 142),
#  ('took', 142),
#  ('thing', 139),
#  ('main', 137),
#  ('10', 136),
#  ('front', 136),
#  ('next', 135),
#  ('left', 135),
#  ('three', 134),
#  ('quite', 134),
#  ('come', 134),
#  ('terrible', 133),
#  ('though', 133),
#  ('lots', 132),
#  ('pay', 131),
#  ('shops', 131),
#  ('things', 131),
#  ('daughter', 130),
#  ('enough', 130),
#  ('child', 130),
#  ('prices', 130),
#  ('30', 129),
#  ('great', 129),
#  ('20', 128),
#  ('saw', 127),
#  ('adults', 127),
#  ('stay', 125),
#  ('mins', 125),
#  ('expected', 124),
#  ('awful', 124),
#  ('worst', 123),
#  ('cost', 123),
#  ('meet', 122),
#  ('waste', 122),
#  ('minute', 122),
#  ('walking', 121),
#  ('busy', 120),
#  ('felt', 120),
#  ('dirty', 119),
#  ('thunder', 118),
#  ('euro', 117),
#  ('less', 117),
#  ('expect', 117),
#  ('toilets', 116),
#  ('quality', 116),
#  ('cant', 114),
#  ('wanted', 113),
#  ('away', 113),
#  ('ever', 112),
#  ('theme', 112),
#  ('disappointment', 112),
#  ('something', 111),
#  ('couldnt', 109),
#  ('several', 109),
#  ('space', 109),
#  ('use', 108),
#  ('price', 107),
#  ('fun', 107),
#  ('came', 107),
#  ('looking', 107),
#  ('worth', 106),
#  ('everywhere', 106),
#  ('save', 106),
#  ('spend', 105),
#  ('restaurant', 105),
#  ('overpriced', 105),
#  ('queued', 105),
#  ('paid', 104),
#  ('recommend', 103),
#  ('feel', 103),
#  ('thought', 103),
#  ('broken', 102),
#  ('mickey', 102),
#  ('6', 102),
#  ('etc', 102),
#  ('drink', 102),
#  ('weather', 101),
#  ('getting', 101),
#  ('stayed', 101),
#  ('lunch', 101),
#  ('anything', 99),
#  ('waited', 98),
#  ('water', 98),
#  ('buy', 97),
#  ('walk', 97),
#  ('meal', 97),
#  ('holiday', 97),
#  ('must', 97),
#  ('lack', 96),
#  ('let', 96),
#  ('broke', 96),
#  ('working', 96),
#  ('booked', 95),
#  ('tired', 95),
#  ('pirates', 95),
#  ('im', 95),
#  ('extremely', 94),
#  ('everyone', 93),
#  ('without', 93),
#  ('orlando', 93),
#  ('actually', 93),
#  ('cast', 92),
#  ('areas', 92),
#  ('although', 92),
#  ('end', 92),
#  ('new', 91),
#  ('studios', 91),
#  ('young', 90),
#  ('40', 90),
#  ('drinks', 90),
#  ('night', 89),
#  ('decided', 88),
#  ('managed', 88),
#  ('try', 88),
#  ('fireworks', 88),
#  ('look', 88),
#  ('trying', 87),
#  ('ridiculous', 87),
#  ('huge', 87),
#  ('son', 87),
#  ('second', 87),
#  ('number', 86),
#  ('seemed', 85),
#  ('character', 85),
#  ('magical', 84),
#  ('15', 84),
#  ('especially', 83),
#  ('attraction', 83),
#  ('customer', 83),
#  ('done', 83),
#  ('four', 82),
#  ('definitely', 82),
#  ('arrived', 82),
#  ('give', 81),
#  ('start', 81),
#  ('shows', 81),
#  ('put', 81),
#  ('full', 81),
#  ('members', 80),
#  ('almost', 80),
#  ('technical', 80),
#  ('wrong', 80),
#  ('asked', 80),
#  ('disabled', 80),
#  ('average', 80),
#  ('90', 79),
#  ('wasnt', 79),
#  ('ago', 79),
#  ('since', 79),
#  ('return', 79),
#  ('prepared', 79),
#  ('8', 78),
#  ('far', 78),
#  ('else', 78),
#  ('princess', 78),
#  ('ones', 78),
#  ('entrance', 77),
#  ('hard', 77),
#  ('wont', 77),
#  ('either', 76),
#  ('part', 76),
#  ('extra', 75),
#  ('person', 75),
#  ('60', 75),
#  ('book', 75),
#  ('past', 74),
#  ('45', 74),
#  ('places', 74),
#  ('absolutely', 74),
#  ('couple', 74),
#  ('outside', 73),
#  ('looked', 73),
#  ('early', 73),
#  ('amount', 72),
#  ('hot', 72),
#  ('shut', 72),
#  ('work', 71),
#  ('disgusting', 71),
#  ('seem', 70),
#  ('week', 70),
#  ('leave', 70),
#  ('seen', 69),
#  ('room', 69),
#  ('parades', 69),
#  ('village', 69),
#  ('yes', 69),
#  ('area', 69),
#  ('visiting', 68),
#  ('land', 68),
#  ('station', 68),
#  ('different', 68),
#  ('enjoyed', 68),
#  ('crowded', 67),
#  ('usa', 67),
#  ('walt', 67),
#  ('help', 67),
#  ('smoke', 67),
#  ('close', 67),
#  ('always', 67),
#  ('whilst', 67),
#  ('bring', 67),
#  ('overall', 67),
#  ('france', 67),
#  ('given', 67),
#  ('passes', 66),
#  ('avoid', 66),
#  ('ok', 66),
#  ('anyone', 66),
#  ('per', 66),
#  ('used', 66),
#  ('standing', 66),
#  ('point', 66),
#  ('evening', 66),
#  ('probably', 66),
#  ('wouldnt', 66),
#  ('maintenance', 66),
#  ('english', 66),
#  ('coffee', 65),
#  ('maybe', 65),
#  ('member', 65),
#  ('late', 65),
#  ('unfortunately', 65),
#  ('7', 65),
#  ('hardly', 65),
#  ('already', 64),
#  ('stand', 64),
#  ('rip', 64),
#  ('nice', 64),
#  ('later', 64),
#  ('tried', 64),
#  ('coaster', 64),
#  ('sit', 63),
#  ('christmas', 63),
#  ('plan', 63),
#  ('may', 63),
#  ('visitors', 62),
#  ('california', 62),
#  ('needs', 62),
#  ('run', 62),
#  ('high', 62),
#  ('thats', 62),
#  ('season', 62),
#  ('american', 61),
#  ('guests', 61),
#  ('fact', 61),
#  ('home', 61),
#  ('eurodisney', 61),
#  ('nearly', 60),
#  ('seems', 59),
#  ('ive', 59),
#  ('inside', 59),
#  ('bought', 59),
#  ('weekend', 59),
#  ('bus', 59),
#  ('check', 59),
#  ('caribbean', 58),
#  ('understand', 58),
#  ('loved', 58),
#  ('star', 58),
#  ('pushing', 58),
#  ('horrible', 57),
#  ('short', 57),
#  ('longer', 57),
#  ('priced', 57),
#  ('despite', 57),
#  ('werent', 57),
#  ('order', 57),
#  ('keep', 57),
#  ('crowds', 56),
#  ('making', 56),
#  ('breakfast', 56),
#  ('returned', 56),
#  ('youre', 56),
#  ('others', 56),
#  ('care', 56),
#  ('peter', 56),
#  ('instead', 56),
#  ('system', 55),
#  ('started', 55),
#  ('smaller', 55),
#  ('castle', 55),
#  ('pan', 55),
#  ('plus', 54),
#  ('hotels', 54),
#  ('anywhere', 54),
#  ('finally', 54),
#  ('major', 54),
#  ('problems', 54),
#  ('mouse', 54),
#  ('plenty', 54),
#  ('rain', 54),
#  ('saying', 53),
#  ('clean', 53),
#  ('refurbishment', 53),
#  ('real', 53),
#  ('jones', 53),
#  ('sad', 52),
#  ('min', 52),
#  ('princesses', 52),
#  ('que', 52),
#  ('stop', 52),
#  ('able', 51),
#  ('right', 51),
#  ('slow', 51),
#  ('taking', 51),
#  ('sure', 51),
#  ('problem', 51),
#  ('friendly', 50),
#  ('twice', 50),
#  ('sorry', 50),
#  ('paying', 50),
#  ('break', 50),
#  ('allowed', 50),
#  ('photo', 50),
#  ('doesnt', 50),
#  ('choice', 50),
#  ('cannot', 50),
#  ('totally', 50),
#  ('behind', 50),
#  ('total', 49),
#  ('kept', 49),
#  ('enjoy', 49),
#  ('side', 49),
#  ('25', 49),
#  ('round', 49),
#  ('meant', 49),
#  ('ages', 48),
#  ('unless', 48),
#  ('summer', 48),
#  ('ended', 48),
#  ('rather', 48),
#  ('dinner', 48),
#  ('worse', 48),
#  ('tell', 48),
#  ('taken', 48),
#  ('indiana', 48),
#  ('available', 47),
#  ('simply', 47),
#  ('eating', 47),
#  ('shop', 47),
#  ('course', 47),
#  ('single', 47),
#  ('security', 47),
#  ('throughout', 47),
#  ('obviously', 46),
#  ('ques', 46),
#  ('fastpass', 46),
#  ('gave', 46),
#  ('review', 46),
#  ('reason', 46),
#  ('compared', 46),
#  ('wife', 46),
#  ('none', 46),
#  ('burger', 46),
#  ('yet', 46),
#  ('uk', 46),
#  ('mind', 46),
#  ('name', 45),
#  ('amazing', 45),
#  ('miserable', 45),
#  ('cafe', 45),
#  ('set', 45),
#  ('chips', 45),
#  ('50', 45),
#  ('adult', 45),
#  ('studio', 45),
#  ('walked', 45),
#  ('fantastic', 45),
#  ('12', 45),
#  ('advice', 45),
#  ('difficult', 45),
#  ('called', 44),
#  ('opened', 44),
#  ('lovely', 44),
#  ('isnt', 44),
#  ('buzz', 44),
#  ('shame', 43),
#  ('near', 43),
#  ('ice', 43),
#  ('value', 43),
#  ('forward', 43),
#  ('biggest', 43),
#  ('best', 43),
#  ('attitude', 43),
#  ('limited', 43),
#  ('school', 43),
#  ('rubbish', 43),
#  ('knew', 43),
#  ('roller', 43),
#  ('apart', 42),
#  ('management', 42),
#  ('holidays', 42),
#  ('please', 42),
#  ('crowd', 42),
#  ('massive', 42),
#  ('peak', 42),
#  ('street', 42),
#  ('free', 42),
#  ('resort', 42),
#  ('unhelpful', 41),
#  ('birthday', 41),
#  ('entry', 41),
#  ('city', 41),
#  ('helpful', 41),
#  ('toilet', 41),
#  ('bother', 41),
#  ('tea', 40),
#  ('five', 40),
#  ('70', 40),
#  ('9', 40),
#  ('boring', 40),
#  ('booking', 39),
#  ('age', 39),
#  ('love', 39),
#  ('husband', 39),
#  ('information', 39),
#  ('case', 39),
#  ('chicken', 39),
#  ('sadly', 39),
#  ('august', 39),
#  ('picture', 38),
#  ('photos', 38),
#  ('crazy', 38),
#  ('gone', 38),
#  ('believe', 38),
#  ('morning', 38),
#  ('impossible', 38),
#  ('feeling', 38),
#  ('clearly', 38),
#  ('complete', 38),
#  ('parents', 38),
#  ('atmosphere', 38),
#  ('might', 38),
#  ('including', 37),
#  ('issues', 37),
#  ('pretty', 37),
#  ('filthy', 37),
#  ('anaheim', 37),
#  ('facilities', 37),
#  ('bag', 37),
#  ('ratatouille', 37),
#  ('shuttle', 37),
#  ('large', 36),
#  ('site', 36),
#  ('seeing', 36),
#  ('supposed', 36),
#  ('reservation', 36),
#  ('someone', 36),
#  ('hand', 36),
#  ('mean', 36),
#  ('rest', 36),
#  ('car', 36),
#  ('non', 36),
#  ('pushed', 36),
#  ('light', 36),
#  ('generally', 35),
#  ('term', 35),
#  ('designated', 35),
#  ('running', 35),
#  ('complaint', 35),
#  ('staying', 35),
#  ('decent', 35),
#  ('ask', 35),
#  ('dlp', 35),
#  ('access', 35),
#  ('excited', 35),
#  ('looks', 35),
#  ('cheaper', 35),
#  ('board', 35),
#  ('truly', 34),
#  ('11', 34),
#  ('offer', 34),
#  ('coming', 34),
#  ('europe', 34),
#  ('saturday', 34),
#  ('turned', 34),
#  ('la', 34),
#  ('move', 34),
#  ('expecting', 34),
#  ('oh', 34),
#  ('chance', 34),
#  ('makes', 34),
#  ('standards', 34),
#  ('closing', 34),
#  ('kid', 33),
#  ('expectations', 33),
#  ('possible', 33),
#  ('general', 33),
#  ('miss', 33),
#  ('empty', 33),
#  ('tour', 33),
#  ('needed', 33),
#  ('stood', 33),
#  ('bottle', 33),
#  ('example', 33),
#  ('speak', 33),
#  ('100', 33),
#  ('pizza', 33),
#  ('wish', 33),
#  ('sort', 32),
#  ('meals', 32),
#  ('head', 32),
#  ('soon', 32),
#  ('merchandise', 32),
#  ('third', 32),
#  ('customers', 32),
#  ('till', 32),
#  ('pm', 32),
#  ('aged', 32),
#  ('packed', 32),
#  ('surprised', 32),
#  ('seriously', 32),
#  ('anniversary', 32),
#  ('costs', 31),
#  ('cut', 31),
#  ('track', 31),
#  ('completely', 31),
#  ('families', 31),
#  ('house', 31),
#  ('gate', 31),
#  ('youll', 31),
#  ('nightmare', 31),
#  ('within', 31),
#  ('afternoon', 31),
#  ('breaking', 31),
#  ('difference', 31),
#  ('america', 31),
#  ('bored', 31),
#  ('standard', 31),
#  ('friends', 31),
#  ('hall', 31),
#  ('changed', 31),
#  ('tours', 31),
#  ('frozen', 31),
#  ('usual', 31),
#  ('youve', 31),
#  ('advance', 30),
#  ('somewhere', 30),
#  ('annoying', 30),
#  ('pre', 30),
#  ('dream', 30),
#  ('cream', 30),
#  ('cars', 30),
#  ('online', 30),
#  ('issue', 30),
#  ('girl', 30),
#  ('push', 30),
#  ('reviews', 30),
#  ('fan', 30),
#  ('served', 30),
#  ('entire', 30),
#  ('badly', 30),
#  ('purchased', 30),
#  ('quickly', 30),
#  ('table', 30),
#  ('forget', 29),
#  ('spending', 29),
#  ('planet', 29),
#  ('employees', 29),
#  ('door', 29),
#  ('outlets', 29),
#  ('younger', 29),
#  ('public', 29),
#  ('numerous', 29),
#  ('dreams', 29),
#  ('face', 29),
#  ('leaving', 29),
#  ('signs', 29),
#  ('months', 29),
#  ('life', 28),
#  ('enter', 28),
#  ('dated', 28),
#  ('idea', 28),
#  ('santa', 28),
#  ('together', 28),
#  ('planned', 28),
#  ('often', 28),
#  ('live', 28),
#  ('travel', 28),
#  ('firework', 28),
#  ('80', 28),
#  ('upset', 28),
#  ('wed', 28),
#  ('change', 28),
#  ('suggest', 28),
#  ('cancelled', 28),
#  ('allow', 28),
#  ('lightyear', 28),
#  ('guess', 28),
#  ('low', 28),
#  ('nights', 28),
#  ('beyond', 28),
#  ('appalling', 28),
#  ('ill', 28),
#  ('met', 28),
#  ('queueing', 28),
#  ('buffet', 28),
#  ('frustrating', 27),
#  ('snacks', 27),
#  ('app', 27),
#  ('watch', 27),
#  ('fault', 27),
#  ('unable', 27),
#  ('toy', 27),
#  ('sitting', 27),
#  ('earlier', 27),
#  ('returning', 27),
#  ('option', 27),
#  ('happy', 27),
#  ('sell', 27),
#  ('offered', 27),
#  ('actual', 27),
#  ('turn', 27),
#  ('11pm', 27),
#  ('childrens', 27),
#  ('group', 27),
#  ('complained', 27),
#  ('website', 26),
#  ('certain', 26),
#  ('disneyworld', 26),
#  ('version', 26),
#  ('across', 26),
#  ('dreadful', 26),
#  ('haunted', 26),
#  ('ripped', 26),
#  ('onto', 26),
#  ('read', 26),
#  ('highly', 26),
#  ('wet', 26),
#  ('theres', 26),
#  ('moving', 26),
#  ('top', 26),
#  ('poorly', 26),
#  ('sunday', 26),
#  ('missed', 26),
#  ('fries', 26),
#  ('except', 26),
#  ('spoke', 26),
#  ('vouchers', 26),
#  ('party', 26),
#  ('ate', 26),
#  ('favourite', 26),
#  ('daughters', 26),
#  ('id', 26),
#  ('means', 26),
#  ('certainly', 26),
#  ('renovation', 25),
#  ('hate', 25),
#  ('negative', 25),
#  ('basic', 25),
#  ('checked', 25),
#  ('stuff', 25),
#  ('travelled', 25),
#  ('along', 25),
#  ('mcdonalds', 25),
#  ('selling', 25),
#  ('purchase', 25),
#  ('shocking', 25),
#  ('using', 25),
#  ('wasted', 25),
#  ('write', 25),
#  ('advise', 25),
#  ('story', 25),
#  ('10am', 25),
#  ('lady', 25),
#  ('basically', 25),
#  ('crush', 25),
#  ('happened', 25),
#  ('joke', 25),
#  ('considering', 25),
#  ('previous', 25),
#  ('literally', 25),
#  ('comparison', 25),
#  ('burgers', 25),
#  ('lacking', 25),
#  ('snow', 25),
#  ('job', 24),
#  ('monday', 24),
#  ('opening', 24),
#  ('menu', 24),
#  ('happen', 24),
#  ('fe', 24),
#  ('dumbo', 24),
#  ('hope', 24),
#  ('entertainment', 24),
#  ('paint', 24),
#  ('experienced', 24),
#  ('mad', 24),
#  ('hell', 24),
#  ('mostly', 24),
#  ('hollywood', 24),
#  ('majority', 24),
#  ('jumping', 24),
#  ('company', 24),
#  ('normal', 24),
#  ('manor', 24),
#  ('matter', 24),
#  ('disneys', 24),
#  ('woman', 24),
#  ('refund', 24),
#  ('smile', 24),
#  ('complain', 24),
#  ('occasions', 24),
#  ('tip', 24),
#  ('adventure', 23),
#  ('cash', 23),
#  ('brand', 23),
#  ('shoving', 23),
#  ('grandchildren', 23),
#  ('smokers', 23),
#  ('dog', 23),
#  ('dark', 23),
#  ('sold', 23),
#  ('girls', 23),
#  ('informed', 23),
#  ('machines', 23),
#  ('loads', 23),
#  ('spot', 23),
#  ('friday', 23),
#  ('became', 23),
#  ('eg', 23),
#  ('eventually', 23),
#  ('wars', 23),
#  ('similar', 23),
#  ('35', 23),
#  ('saved', 23),
#  ('june', 23),
#  ('weve', 23),
#  ('sequoia', 23),
#  ('desk', 23),
#  ('compare', 22),
#  ('today', 22),
#  ('rooms', 22),
#  ('sometimes', 22),
#  ('store', 22),
#  ('date', 22),
#  ('shopping', 22),
#  ('bags', 22),
#  ('meeting', 22),
#  ('sat', 22),
#  ('covered', 22),
#  ('display', 22),
#  ('options', 22),
#  ('parts', 22),
#  ('starting', 22),
#  ('gates', 22),
#  ('thinking', 22),
#  ('asking', 22),
#  ('policy', 22),
#  ('warm', 22),
#  ('brought', 22),
#  ('notice', 22),
#  ('refused', 22),
#  ('approx', 22),
#  ('operating', 22),
#  ('closures', 22),
#  ('bothered', 22),
#  ('noticed', 22),
#  ('skip', 21),
#  ('heard', 21),
#  ('effort', 21),
#  ('parking', 21),
#  ('states', 21),
#  ('previously', 21),
#  ('size', 21),
#  ('included', 21),
#  ('march', 21),
#  ('straight', 21),
#  ('nowhere', 21),
#  ('rate', 21),
#  ('received', 21),
#  ('goes', 21),
#  ('fully', 21),
#  ('seating', 21),
#  ('autographs', 21),
#  ('deal', 21),
#  ('raining', 21),
#  ('popular', 21),
#  ('fine', 21),
#  ('call', 21),
#  ('gets', 21),
#  ('level', 21),
#  ('constantly', 21),
#  ('building', 21),
#  ('remember', 21),
#  ('havent', 21),
#  ('winter', 20),
#  ('december', 20),
#  ('unfriendly', 20),
#  ('elsewhere', 20),
#  ('unpleasant', 20),
#  ('lost', 20),
#  ('organised', 20),
#  ('tokyo', 20),
#  ('exactly', 20),
#  ('cigarette', 20),
#  ('bottles', 20),
#  ('tower', 20),
#  ('rock', 20),
#  ('afraid', 20),
#  ('floor', 20),
#  ('freezing', 20),
#  ('hated', 20),
#  ('guest', 20),
#  ('cheap', 20),
#  ('safety', 20),
#  ('imagine', 20),
#  ('special', 20),
#  ('pack', 20),
#  ('halloween', 20),
#  ('n', 20),
#  ('training', 20),
#  ('autograph', 20),
#  ('properly', 20),
#  ('paper', 20),
#  ('arrive', 20),
#  ('phantom', 20),
#  ('boys', 20),
#  ('positive', 20),
#  ('wonder', 20),
#  ('shabby', 20),
#  ('missing', 20),
#  ('maintained', 19),
#  ('easter', 19),
#  ('signage', 19),
#  ('hong', 19),
#  ('chose', 19),
#  ('cups', 19),
#  ('glad', 19),
#  ('man', 19),
#  ('boat', 19),
#  ('barely', 19),
#  ('treated', 19),
#  ('quiet', 19),
#  ('earth', 19),
#  ('telling', 19),
#  ('arent', 19),
#  ('stopped', 19),
#  ('buying', 19),
#  ('card', 19),
#  ('wandering', 19),
#  ('november', 19),
#  ('ten', 19),
#  ('amusement', 19),
#  ('simple', 19),
#  ('tram', 19),
#  ('extortionate', 19),
#  ('email', 19),
#  ('manager', 19),
#  ('game', 19),
#  ('shocked', 19),
#  ('older', 19),
#  ('consider', 19),
#  ('smelly', 19),
#  ('thousands', 19),
#  ('junk', 19),
#  ('airport', 19),
#  ('blue', 19),
#  ('occasion', 19),
#  ('note', 19),
#  ('beautiful', 19),
#  ('white', 19),
#  ('following', 19),
#  ('opinion', 19),
#  ('visits', 19),
#  ('meaning', 18),
#  ('75', 18),
#  ('kong', 18),
#  ('weeks', 18),
#  ('usually', 18),
#  ('incredibly', 18),
#  ('list', 18),
#  ('faces', 18),
#  ...]

# %%
word_counts_df3 = pd.DataFrame(word_counts.most_common(50))
word_counts_df3.columns = ['word', 'counts']

# %%
plt.figure(figsize =(10,8))
sns.barplot(x = 'counts', y = 'word', data = word_counts_df3)
# Out:
# <AxesSubplot:xlabel='counts', ylabel='word'>

# %%
# 시각화 
wordcloud = WordCloud(background_color = 'white',
                      max_words = 100,
                      relative_scaling = 0.3,
                      width = 800,
                      height = 400).generate_from_frequencies(word_counts)
plt.figure(figsize = (15,10))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %%
fig, ax = plt.subplots(3,1,figsize =(12,8))
ax[0].plot(N_HK['Reviewer_Location'].value_counts().head(5))
ax[1].plot(N_C['Reviewer_Location'].value_counts().head(5))
ax[2].plot(N_P['Reviewer_Location'].value_counts().head(5))
